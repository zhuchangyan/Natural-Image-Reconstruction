# %%
# -*- coding: utf-8 -*-
"""
Created on Fri May  6 15:14:16 2022

@author: zhuch
"""

# -*- coding: utf-8 -*-
"""
Created on Thu May  5 17:30:53 2022

@author: zhuch
"""

import pickle

import numpy as np
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda, Compose
import matplotlib.pyplot as plt
import torch.nn.functional as F
import h5py
#%%

# with open("speckle.dat", 'rb') as f:
#     input_list = pickle.load(f)

# with open("SLM.dat", 'rb') as f:
#     output_list =pickle.load(f)
    
#%%

# with open("data/experiment results/Speckle_20x_200um_Round_Scale-2.5x_Natural_M_2_10238_112x112.dat", 'rb') as f:
#     input_list = pickle.load(f)

# with open("data/experiment results/Natural_10238.dat", 'rb') as f:
#     output_list =pickle.load(f)
    
#%%

with open("data/Natural_temp_cifar/Speckle_20x_400um_Round_Scale-2x_Natural_M_016_T75_112x112_5000.dat", 'rb') as f:
    input_list = pickle.load(f)

with open("data/Natural_temp_cifar/Natural_Order_5000.dat", 'rb') as f:
    output_list =pickle.load(f)


#%%
# pathname = "data/natcom/Data_1m.h5"
    

# hf = h5py.File(pathname, 'r')
# name1 = 'Training/Original_images/ImageNet'
# name2 = 'Training/Speckle_images/ImageNet'

# output_list = hf[name1]
# input_list = hf[name2]

# %%
#%%
import matplotlib.pyplot as plt

idx = np.random.randint(0,5000)
# idx = 2600

plt.figure()
plt.subplot(121)
plt.imshow(output_list[idx], cmap = 'gray')
plt.subplot(122)
plt.imshow(input_list[idx].reshape(112,112), cmap = 'gray')
plt.show()

# %%
np.shape(rn)
# Out:
# (5000,)

# %%
import pickle

# rn = np.random.randint(0,5000,5000)
# with open("data/random_number5000.dat", 'wb') as f:
#     pickle.dump(rn,f)
    
with open("data/random_number5000.dat", 'rb') as f:
    rn = pickle.load(f)

# %%
#%%
# s = input_list[5]
# x = np.arange(0,112,1)
# y = np.arange(0,112,1)
# X,Y = np.meshgrid(x,y)
# plt.figure()
# ax = plt.axes(projection='3d')
# ax.scatter(X,Y,s.reshape(112,112), cmap='viridis')
# # plt.colorbar()
# plt.show()

#%%
N_sample = 5000
start_id = 0
train_rate = 0.9
train_set_number = int(train_rate*N_sample)

input_dim = (112,112)
output_dim = (64,64)
out_dim = 64

input_H = np.array(input_list[rn]).reshape(-1,1, *input_dim)
label = np.array(output_list[rn]).reshape(-1,1, *output_dim)

train_number = np.arange(start_id,start_id + N_sample, dtype ='int')
np.random.shuffle(train_number)
#
x_train = input_H[train_number[0:train_set_number]]
x_test = input_H[train_number[train_set_number:N_sample]]

y_train =label[train_number[0:train_set_number]]
y_test = label[train_number[train_set_number:N_sample]]

x_train = torch.FloatTensor(x_train/255.0)
x_test = torch.FloatTensor(x_test/255.0)

# x_train = torch.sqrt(x_train)
# x_test = torch.sqrt(x_test)

y_train = torch.FloatTensor(y_train/255.0)
y_test = torch.FloatTensor(y_test/255.0)
    
    

#%%
# del input_list
# del output_list
# del input_H
# del label
#%%
torch.cuda.empty_cache()

# %%
batch_size = 50

# create data loaders
train_dataloader = DataLoader(list(zip(x_train, y_train)), batch_size = batch_size )
test_dataloader = DataLoader(list(zip(x_test,y_test)),  batch_size = batch_size )

# %%
import math

class complexLayer(nn.Module):
    """ Custom Linear layer but mimics a standard linear layer """
    def __init__(self, size_in, size_out):
        super().__init__()
        self.size_in, self.size_out = size_in, size_out
        weights1 = torch.Tensor(size_out, size_in)
        self.weights1 = nn.Parameter(weights1)  # nn.Parameter is a Tensor that's a module parameter.
#         weights2 = torch.Tensor(size_out, size_in)
#         self.weights2 = nn.Parameter(weights2)

        # initialize weights and biases
        nn.init.kaiming_uniform_(self.weights1, a=math.sqrt(5)) # weight init
#         nn.init.kaiming_uniform_(self.weights2, a=math.sqrt(5)) # weight init


    def forward(self, x):
        x1 = torch.mm(x,self.weights1.t())
#         x1 = torch.square(torch.mm(torch.cos(x),self.weights1.t()))
#         x2 = torch.square(torch.mm(torch.sin(x),self.weights2.t()))
#         x =  torch.add(x1,x2)
        return x1

#%%

device = "cuda"
import torch.nn.functional as F

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.my1 = complexLayer(112*112, out_dim*out_dim)
        self.flatten = nn.Flatten()

    def forward(self, x):
        x = self.flatten(x)
        x = self.my1(x)
        x = x.view(-1, 1, out_dim, out_dim)
        return x

model = NeuralNetwork().to(device)

# %% [markdown]
# I = np.square(abs( T* Input_image))
#
# I = T' * Input_image
#
# Input_image: 64x64
# I: 112x112
# T: 4096x (112x112)

# %%
# ######## Define model
# device = 'cuda'
# class NeuralNetwork(nn.Module):
#     def __init__(self):
#         super(NeuralNetwork, self).__init__()
#         self.fc1 = nn.Linear(112*112, 28*28)
#         self.flatten = nn.Flatten()
        
#     def forward(self, x):
#         x3 = self.flatten(x)
#         x4 = self.fc1(x3)
#         x5 = x4.view(-1,1,28,28)
#         return x5

# model = NeuralNetwork().to(device)
# from torchsummary import summary
# summary(model, (1, 112, 112))

# %%
# device = 'cuda'
# Nnodes = 4096

# class NeuralNetwork(nn.Module):
#     def __init__(self):
#         super(NeuralNetwork, self).__init__()
#         self.fc1 = nn.Linear(112*112, Nnodes)
#         self.fc2 = nn.Linear(Nnodes, 28*28)
#         self.dp = nn.Dropout(0.3)
#         self.BN = nn.BatchNorm1d(Nnodes)
#         self.BN2 = nn.BatchNorm1d(28*28)  
#         self.flatten = nn.Flatten()
        
#     def forward(self, x):
#         x = self.flatten(x)
#         x = self.BN(self.dp(F.relu(self.fc1(x))))
#         x = self.BN2(self.dp(F.sigmoid(self.fc2(x))))
#         # x = self.dp(F.relu(self.fc2(x)))
#         x = x.view(-1,1,28,28)
#         return x

# model = NeuralNetwork().to(device)
# from torchsummary import summary
# summary(model, (1, 112, 112))

# %%
# !pip install torchsummary

# %%
#%%
import ssim
from torch.optim.lr_scheduler import ReduceLROnPlateau

# loss_fn = ssim.SSIM()
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# optimizer = Nadam(model.parameters(), lr=1e-3)
scheduler = ReduceLROnPlateau(optimizer)


def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        
        optimizer.step()

        if batch % 10 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"Train loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    return loss
#     return loss.cpu().detach().numpy()       
            
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
    test_loss /= num_batches
    print(f"Test Loss:  {test_loss:>8f} \n")
    return test_loss

# %%
#%%  Neural network training


epochs = 200

Loss_train = []
Loss_test = []
steps = []


best_loss = 1.0


for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loss = train(train_dataloader, model, loss_fn, optimizer)
    test_loss = test(test_dataloader, model, loss_fn)
    Loss_train.append(train_loss)
    Loss_test.append(test_loss)
    if test_loss<best_loss:
        best_loss = test_loss
    steps.append(t)
    scheduler.step(test_loss)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Train loss: 0.272284  [    0/ 4500]
# Train loss: 0.450806  [  500/ 4500]
# Train loss: 0.269275  [ 1000/ 4500]
# Train loss: 0.150603  [ 1500/ 4500]
# Train loss: 0.079353  [ 2000/ 4500]
# Train loss: 0.067278  [ 2500/ 4500]
# Train loss: 0.057517  [ 3000/ 4500]
# Train loss: 0.057761  [ 3500/ 4500]
# Train loss: 0.061069  [ 4000/ 4500]
# Test Loss:  0.052633
#
# Epoch 2
# -------------------------------
# Train loss: 0.049257  [    0/ 4500]
# Train loss: 0.051946  [  500/ 4500]
# Train loss: 0.051386  [ 1000/ 4500]
# Train loss: 0.048468  [ 1500/ 4500]
# Train loss: 0.045492  [ 2000/ 4500]
# Train loss: 0.047808  [ 2500/ 4500]
# Train loss: 0.042932  [ 3000/ 4500]
# Train loss: 0.045531  [ 3500/ 4500]
# Train loss: 0.048535  [ 4000/ 4500]
# Test Loss:  0.044635
#
# Epoch 3
# -------------------------------
# Train loss: 0.044580  [    0/ 4500]
# Train loss: 0.040931  [  500/ 4500]
# Train loss: 0.043981  [ 1000/ 4500]
# Train loss: 0.041635  [ 1500/ 4500]
# Train loss: 0.037916  [ 2000/ 4500]
# Train loss: 0.036005  [ 2500/ 4500]
# Train loss: 0.036341  [ 3000/ 4500]
# Train loss: 0.040042  [ 3500/ 4500]
# Train loss: 0.043216  [ 4000/ 4500]
# Test Loss:  0.038517
#
# Epoch 4
# -------------------------------
# Train loss: 0.035752  [    0/ 4500]
# Train loss: 0.035080  [  500/ 4500]
# Train loss: 0.038358  [ 1000/ 4500]
# Train loss: 0.037526  [ 1500/ 4500]
# Train loss: 0.033508  [ 2000/ 4500]
# Train loss: 0.031125  [ 2500/ 4500]
# Train loss: 0.031553  [ 3000/ 4500]
# Train loss: 0.037655  [ 3500/ 4500]
# Train loss: 0.037897  [ 4000/ 4500]
# Test Loss:  0.034439
#
# Epoch 5
# -------------------------------
# Train loss: 0.030882  [    0/ 4500]
# Train loss: 0.031331  [  500/ 4500]
# Train loss: 0.032220  [ 1000/ 4500]
# Train loss: 0.033452  [ 1500/ 4500]
# Train loss: 0.030740  [ 2000/ 4500]
# Train loss: 0.027827  [ 2500/ 4500]
# Train loss: 0.028300  [ 3000/ 4500]
# Train loss: 0.032911  [ 3500/ 4500]
# Train loss: 0.034110  [ 4000/ 4500]
# Test Loss:  0.031670
#
# Epoch 6
# -------------------------------
# Train loss: 0.028427  [    0/ 4500]
# Train loss: 0.028858  [  500/ 4500]
# Train loss: 0.029364  [ 1000/ 4500]
# Train loss: 0.030466  [ 1500/ 4500]
# Train loss: 0.029679  [ 2000/ 4500]
# Train loss: 0.026112  [ 2500/ 4500]
# Train loss: 0.026013  [ 3000/ 4500]
# Train loss: 0.029236  [ 3500/ 4500]
# Train loss: 0.031830  [ 4000/ 4500]
# Test Loss:  0.030047
#
# Epoch 7
# -------------------------------
# Train loss: 0.026801  [    0/ 4500]
# Train loss: 0.026695  [  500/ 4500]
# Train loss: 0.026725  [ 1000/ 4500]
# Train loss: 0.028403  [ 1500/ 4500]
# Train loss: 0.027660  [ 2000/ 4500]
# Train loss: 0.024106  [ 2500/ 4500]
# Train loss: 0.024289  [ 3000/ 4500]
# Train loss: 0.026751  [ 3500/ 4500]
# Train loss: 0.030117  [ 4000/ 4500]
# Test Loss:  0.029559
#
# Epoch 8
# -------------------------------
# Train loss: 0.026526  [    0/ 4500]
# Train loss: 0.024887  [  500/ 4500]
# Train loss: 0.024420  [ 1000/ 4500]
# Train loss: 0.026556  [ 1500/ 4500]
# Train loss: 0.025734  [ 2000/ 4500]
# Train loss: 0.022117  [ 2500/ 4500]
# Train loss: 0.022453  [ 3000/ 4500]
# Train loss: 0.024918  [ 3500/ 4500]
# Train loss: 0.028188  [ 4000/ 4500]
# Test Loss:  0.029635
#
# Epoch 9
# -------------------------------
# Train loss: 0.026614  [    0/ 4500]
# Train loss: 0.022919  [  500/ 4500]
# Train loss: 0.023164  [ 1000/ 4500]
# Train loss: 0.024845  [ 1500/ 4500]
# Train loss: 0.024068  [ 2000/ 4500]
# Train loss: 0.020384  [ 2500/ 4500]
# Train loss: 0.020560  [ 3000/ 4500]
# Train loss: 0.023234  [ 3500/ 4500]
# Train loss: 0.026046  [ 4000/ 4500]
# Test Loss:  0.029376
#
# Epoch 10
# -------------------------------
# Train loss: 0.026016  [    0/ 4500]
# Train loss: 0.021015  [  500/ 4500]
# Train loss: 0.021975  [ 1000/ 4500]
# Train loss: 0.023093  [ 1500/ 4500]
# Train loss: 0.022556  [ 2000/ 4500]
# Train loss: 0.018993  [ 2500/ 4500]
# Train loss: 0.019052  [ 3000/ 4500]
# Train loss: 0.021834  [ 3500/ 4500]
# Train loss: 0.024076  [ 4000/ 4500]
# Test Loss:  0.028451
#
# Epoch 11
# -------------------------------
# Train loss: 0.024551  [    0/ 4500]
# Train loss: 0.019407  [  500/ 4500]
# Train loss: 0.020324  [ 1000/ 4500]
# Train loss: 0.021575  [ 1500/ 4500]
# Train loss: 0.021183  [ 2000/ 4500]
# Train loss: 0.017718  [ 2500/ 4500]
# Train loss: 0.017937  [ 3000/ 4500]
# Train loss: 0.020672  [ 3500/ 4500]
# Train loss: 0.022687  [ 4000/ 4500]
# Test Loss:  0.027194
#
# Epoch 12
# -------------------------------
# Train loss: 0.022689  [    0/ 4500]
# Train loss: 0.018203  [  500/ 4500]
# Train loss: 0.018563  [ 1000/ 4500]
# Train loss: 0.020324  [ 1500/ 4500]
# Train loss: 0.019936  [ 2000/ 4500]
# Train loss: 0.016581  [ 2500/ 4500]
# Train loss: 0.017012  [ 3000/ 4500]
# Train loss: 0.019438  [ 3500/ 4500]
# Train loss: 0.021862  [ 4000/ 4500]
# Test Loss:  0.025783
#
# Epoch 13
# -------------------------------
# Train loss: 0.020666  [    0/ 4500]
# Train loss: 0.017396  [  500/ 4500]
# Train loss: 0.017201  [ 1000/ 4500]
# Train loss: 0.019200  [ 1500/ 4500]
# Train loss: 0.018796  [ 2000/ 4500]
# Train loss: 0.015530  [ 2500/ 4500]
# Train loss: 0.016107  [ 3000/ 4500]
# Train loss: 0.018135  [ 3500/ 4500]
# Train loss: 0.021251  [ 4000/ 4500]
# Test Loss:  0.024131
#
# Epoch 14
# -------------------------------
# Train loss: 0.018372  [    0/ 4500]
# Train loss: 0.016705  [  500/ 4500]
# Train loss: 0.016433  [ 1000/ 4500]
# Train loss: 0.018211  [ 1500/ 4500]
# Train loss: 0.017762  [ 2000/ 4500]
# Train loss: 0.014605  [ 2500/ 4500]
# Train loss: 0.015165  [ 3000/ 4500]
# Train loss: 0.016916  [ 3500/ 4500]
# Train loss: 0.020480  [ 4000/ 4500]
# Test Loss:  0.022408
#
# Epoch 15
# -------------------------------
# Train loss: 0.016001  [    0/ 4500]
# Train loss: 0.015826  [  500/ 4500]
# Train loss: 0.016130  [ 1000/ 4500]
# Train loss: 0.017376  [ 1500/ 4500]
# Train loss: 0.016981  [ 2000/ 4500]
# Train loss: 0.013804  [ 2500/ 4500]
# Train loss: 0.014247  [ 3000/ 4500]
# Train loss: 0.015874  [ 3500/ 4500]
# Train loss: 0.019377  [ 4000/ 4500]
# Test Loss:  0.020943
#
# Epoch 16
# -------------------------------
# Train loss: 0.013961  [    0/ 4500]
# Train loss: 0.014733  [  500/ 4500]
# Train loss: 0.015906  [ 1000/ 4500]
# Train loss: 0.016657  [ 1500/ 4500]
# Train loss: 0.016458  [ 2000/ 4500]
# Train loss: 0.013099  [ 2500/ 4500]
# Train loss: 0.013382  [ 3000/ 4500]
# Train loss: 0.014981  [ 3500/ 4500]
# Train loss: 0.018048  [ 4000/ 4500]
# Test Loss:  0.019852
#
# Epoch 17
# -------------------------------
# Train loss: 0.012423  [    0/ 4500]
# Train loss: 0.013617  [  500/ 4500]
# Train loss: 0.015559  [ 1000/ 4500]
# Train loss: 0.016009  [ 1500/ 4500]
# Train loss: 0.016052  [ 2000/ 4500]
# Train loss: 0.012458  [ 2500/ 4500]
# Train loss: 0.012565  [ 3000/ 4500]
# Train loss: 0.014168  [ 3500/ 4500]
# Train loss: 0.016652  [ 4000/ 4500]
# Test Loss:  0.019080
#
# Epoch 18
# -------------------------------
# Train loss: 0.011323  [    0/ 4500]
# Train loss: 0.012631  [  500/ 4500]
# Train loss: 0.015089  [ 1000/ 4500]
# Train loss: 0.015370  [ 1500/ 4500]
# Train loss: 0.015561  [ 2000/ 4500]
# Train loss: 0.011842  [ 2500/ 4500]
# Train loss: 0.011805  [ 3000/ 4500]
# Train loss: 0.013402  [ 3500/ 4500]
# Train loss: 0.015339  [ 4000/ 4500]
# Test Loss:  0.018511
#
# Epoch 19
# -------------------------------
# Train loss: 0.010504  [    0/ 4500]
# Train loss: 0.011806  [  500/ 4500]
# Train loss: 0.014674  [ 1000/ 4500]
# Train loss: 0.014673  [ 1500/ 4500]
# Train loss: 0.014968  [ 2000/ 4500]
# Train loss: 0.011250  [ 2500/ 4500]
# Train loss: 0.011100  [ 3000/ 4500]
# Train loss: 0.012746  [ 3500/ 4500]
# Train loss: 0.014177  [ 4000/ 4500]
# Test Loss:  0.018060
#
# Epoch 20
# -------------------------------
# Train loss: 0.009851  [    0/ 4500]
# Train loss: 0.011117  [  500/ 4500]
# Train loss: 0.014373  [ 1000/ 4500]
# Train loss: 0.013942  [ 1500/ 4500]
# Train loss: 0.014362  [ 2000/ 4500]
# Train loss: 0.010669  [ 2500/ 4500]
# Train loss: 0.010418  [ 3000/ 4500]
# Train loss: 0.012176  [ 3500/ 4500]
# Train loss: 0.013179  [ 4000/ 4500]
# Test Loss:  0.017709
#
# Epoch 21
# -------------------------------
# Train loss: 0.009328  [    0/ 4500]
# Train loss: 0.010484  [  500/ 4500]
# Train loss: 0.014102  [ 1000/ 4500]
# Train loss: 0.013254  [ 1500/ 4500]
# Train loss: 0.013783  [ 2000/ 4500]
# Train loss: 0.010123  [ 2500/ 4500]
# Train loss: 0.009773  [ 3000/ 4500]
# Train loss: 0.011627  [ 3500/ 4500]
# Train loss: 0.012347  [ 4000/ 4500]
# Test Loss:  0.017522
#
# Epoch 22
# -------------------------------
# Train loss: 0.008973  [    0/ 4500]
# Train loss: 0.009927  [  500/ 4500]
# Train loss: 0.013750  [ 1000/ 4500]
# Train loss: 0.012636  [ 1500/ 4500]
# Train loss: 0.013142  [ 2000/ 4500]
# Train loss: 0.009690  [ 2500/ 4500]
# Train loss: 0.009206  [ 3000/ 4500]
# Train loss: 0.011077  [ 3500/ 4500]
# Train loss: 0.011513  [ 4000/ 4500]
# Test Loss:  0.017326
#
# Epoch 23
# -------------------------------
# Train loss: 0.008619  [    0/ 4500]
# Train loss: 0.009474  [  500/ 4500]
# Train loss: 0.013337  [ 1000/ 4500]
# Train loss: 0.012101  [ 1500/ 4500]
# Train loss: 0.012502  [ 2000/ 4500]
# Train loss: 0.009257  [ 2500/ 4500]
# Train loss: 0.008723  [ 3000/ 4500]
# Train loss: 0.010484  [ 3500/ 4500]
# Train loss: 0.010824  [ 4000/ 4500]
# Test Loss:  0.017139
#
# Epoch 24
# -------------------------------
# Train loss: 0.008261  [    0/ 4500]
# Train loss: 0.008967  [  500/ 4500]
# Train loss: 0.012787  [ 1000/ 4500]
# Train loss: 0.011662  [ 1500/ 4500]
# Train loss: 0.011860  [ 2000/ 4500]
# Train loss: 0.008878  [ 2500/ 4500]
# Train loss: 0.008304  [ 3000/ 4500]
# Train loss: 0.009906  [ 3500/ 4500]
# Train loss: 0.010259  [ 4000/ 4500]
# Test Loss:  0.017070
#
# Epoch 25
# -------------------------------
# Train loss: 0.008028  [    0/ 4500]
# Train loss: 0.008526  [  500/ 4500]
# Train loss: 0.012168  [ 1000/ 4500]
# Train loss: 0.011264  [ 1500/ 4500]
# Train loss: 0.011163  [ 2000/ 4500]
# Train loss: 0.008508  [ 2500/ 4500]
# Train loss: 0.007926  [ 3000/ 4500]
# Train loss: 0.009311  [ 3500/ 4500]
# Train loss: 0.009711  [ 4000/ 4500]
# Test Loss:  0.016980
#
# Epoch 26
# -------------------------------
# Train loss: 0.007778  [    0/ 4500]
# Train loss: 0.008284  [  500/ 4500]
# Train loss: 0.011642  [ 1000/ 4500]
# Train loss: 0.011009  [ 1500/ 4500]
# Train loss: 0.010530  [ 2000/ 4500]
# Train loss: 0.008212  [ 2500/ 4500]
# Train loss: 0.007686  [ 3000/ 4500]
# Train loss: 0.008843  [ 3500/ 4500]
# Train loss: 0.009367  [ 4000/ 4500]
# Test Loss:  0.016947
#
# Epoch 27
# -------------------------------
# Train loss: 0.007599  [    0/ 4500]
# Train loss: 0.008078  [  500/ 4500]
# Train loss: 0.011263  [ 1000/ 4500]
# Train loss: 0.010766  [ 1500/ 4500]
# Train loss: 0.009992  [ 2000/ 4500]
# Train loss: 0.008087  [ 2500/ 4500]
# Train loss: 0.007481  [ 3000/ 4500]
# Train loss: 0.008690  [ 3500/ 4500]
# Train loss: 0.009204  [ 4000/ 4500]
# Test Loss:  0.017252
#
# Epoch 28
# -------------------------------
# Train loss: 0.007743  [    0/ 4500]
# Train loss: 0.008065  [  500/ 4500]
# Train loss: 0.010930  [ 1000/ 4500]
# Train loss: 0.010624  [ 1500/ 4500]
# Train loss: 0.009538  [ 2000/ 4500]
# Train loss: 0.007948  [ 2500/ 4500]
# Train loss: 0.007364  [ 3000/ 4500]
# Train loss: 0.008290  [ 3500/ 4500]
# Train loss: 0.009083  [ 4000/ 4500]
# Test Loss:  0.017232
#
# Epoch 29
# -------------------------------
# Train loss: 0.007585  [    0/ 4500]
# Train loss: 0.008056  [  500/ 4500]
# Train loss: 0.010698  [ 1000/ 4500]
# Train loss: 0.010558  [ 1500/ 4500]
# Train loss: 0.009522  [ 2000/ 4500]
# Train loss: 0.007977  [ 2500/ 4500]
# Train loss: 0.007506  [ 3000/ 4500]
# Train loss: 0.008377  [ 3500/ 4500]
# Train loss: 0.009164  [ 4000/ 4500]
# Test Loss:  0.017531
#
# Epoch 30
# -------------------------------
# Train loss: 0.007704  [    0/ 4500]
# Train loss: 0.008262  [  500/ 4500]
# Train loss: 0.010878  [ 1000/ 4500]
# Train loss: 0.010678  [ 1500/ 4500]
# Train loss: 0.009752  [ 2000/ 4500]
# Train loss: 0.008297  [ 2500/ 4500]
# Train loss: 0.007698  [ 3000/ 4500]
# Train loss: 0.008729  [ 3500/ 4500]
# Train loss: 0.009799  [ 4000/ 4500]
# Test Loss:  0.018283
#
# Epoch 31
# -------------------------------
# Train loss: 0.008313  [    0/ 4500]
# Train loss: 0.008851  [  500/ 4500]
# Train loss: 0.011500  [ 1000/ 4500]
# Train loss: 0.011303  [ 1500/ 4500]
# Train loss: 0.010885  [ 2000/ 4500]
# Train loss: 0.009299  [ 2500/ 4500]
# Train loss: 0.008763  [ 3000/ 4500]
# Train loss: 0.010099  [ 3500/ 4500]
# Train loss: 0.010978  [ 4000/ 4500]
# Test Loss:  0.019857
#
# Epoch 32
# -------------------------------
# Train loss: 0.009620  [    0/ 4500]
# Train loss: 0.010448  [  500/ 4500]
# Train loss: 0.012772  [ 1000/ 4500]
# Train loss: 0.013162  [ 1500/ 4500]
# Train loss: 0.012754  [ 2000/ 4500]
# Train loss: 0.011016  [ 2500/ 4500]
# Train loss: 0.010779  [ 3000/ 4500]
# Train loss: 0.011962  [ 3500/ 4500]
# Train loss: 0.013409  [ 4000/ 4500]
# Test Loss:  0.021370
#
# Epoch 33
# -------------------------------
# Train loss: 0.011196  [    0/ 4500]
# Train loss: 0.012091  [  500/ 4500]
# Train loss: 0.014663  [ 1000/ 4500]
# Train loss: 0.014835  [ 1500/ 4500]
# Train loss: 0.015393  [ 2000/ 4500]
# Train loss: 0.013238  [ 2500/ 4500]
# Train loss: 0.012918  [ 3000/ 4500]
# Train loss: 0.014823  [ 3500/ 4500]
# Train loss: 0.016493  [ 4000/ 4500]
# Test Loss:  0.023303
#
# Epoch 34
# -------------------------------
# Train loss: 0.013107  [    0/ 4500]
# Train loss: 0.015554  [  500/ 4500]
# Train loss: 0.017147  [ 1000/ 4500]
# Train loss: 0.017210  [ 1500/ 4500]
# Train loss: 0.018003  [ 2000/ 4500]
# Train loss: 0.016024  [ 2500/ 4500]
# Train loss: 0.015649  [ 3000/ 4500]
# Train loss: 0.017777  [ 3500/ 4500]
# Train loss: 0.020633  [ 4000/ 4500]
# Test Loss:  0.026102
#
# Epoch 35
# -------------------------------
# Train loss: 0.016198  [    0/ 4500]
# Train loss: 0.018699  [  500/ 4500]
# Train loss: 0.019483  [ 1000/ 4500]
# Train loss: 0.019720  [ 1500/ 4500]
# Train loss: 0.020494  [ 2000/ 4500]
# Train loss: 0.017508  [ 2500/ 4500]
# Train loss: 0.017379  [ 3000/ 4500]
# Train loss: 0.019979  [ 3500/ 4500]
# Train loss: 0.024626  [ 4000/ 4500]
# Test Loss:  0.029639
#
# Epoch 36
# -------------------------------
# Train loss: 0.020526  [    0/ 4500]
# Train loss: 0.023394  [  500/ 4500]
# Train loss: 0.021568  [ 1000/ 4500]
# Train loss: 0.021833  [ 1500/ 4500]
# Train loss: 0.022121  [ 2000/ 4500]
# Train loss: 0.019842  [ 2500/ 4500]
# Train loss: 0.019988  [ 3000/ 4500]
# Train loss: 0.023751  [ 3500/ 4500]
# Train loss: 0.026550  [ 4000/ 4500]
# Test Loss:  0.035377
#
# Epoch 37
# -------------------------------
# Train loss: 0.026909  [    0/ 4500]
# Train loss: 0.026670  [  500/ 4500]
# Train loss: 0.023673  [ 1000/ 4500]
# Train loss: 0.023081  [ 1500/ 4500]
# Train loss: 0.022662  [ 2000/ 4500]
# Train loss: 0.020635  [ 2500/ 4500]
# Train loss: 0.021004  [ 3000/ 4500]
# Train loss: 0.025123  [ 3500/ 4500]
# Train loss: 0.028686  [ 4000/ 4500]
# Test Loss:  0.039479
#
# Epoch 38
# -------------------------------
# Train loss: 0.031869  [    0/ 4500]
# Train loss: 0.006872  [  500/ 4500]
# Train loss: 0.008176  [ 1000/ 4500]
# Train loss: 0.006739  [ 1500/ 4500]
# Train loss: 0.005627  [ 2000/ 4500]
# Train loss: 0.005545  [ 2500/ 4500]
# Train loss: 0.004504  [ 3000/ 4500]
# Train loss: 0.005245  [ 3500/ 4500]
# Train loss: 0.005052  [ 4000/ 4500]
# Test Loss:  0.012280
#
# Epoch 39
# -------------------------------
# Train loss: 0.004280  [    0/ 4500]
# Train loss: 0.004798  [  500/ 4500]
# Train loss: 0.004827  [ 1000/ 4500]
# Train loss: 0.006266  [ 1500/ 4500]
# Train loss: 0.005419  [ 2000/ 4500]
# Train loss: 0.005430  [ 2500/ 4500]
# Train loss: 0.004390  [ 3000/ 4500]
# Train loss: 0.005200  [ 3500/ 4500]
# Train loss: 0.005058  [ 4000/ 4500]
# Test Loss:  0.012279
#
# Epoch 40
# -------------------------------
# Train loss: 0.004261  [    0/ 4500]
# Train loss: 0.004781  [  500/ 4500]
# Train loss: 0.004808  [ 1000/ 4500]
# Train loss: 0.006234  [ 1500/ 4500]
# Train loss: 0.005414  [ 2000/ 4500]
# Train loss: 0.005398  [ 2500/ 4500]
# Train loss: 0.004365  [ 3000/ 4500]
# Train loss: 0.005161  [ 3500/ 4500]
# Train loss: 0.005066  [ 4000/ 4500]
# Test Loss:  0.012289
#
# Epoch 41
# -------------------------------
# Train loss: 0.004255  [    0/ 4500]
# Train loss: 0.004779  [  500/ 4500]
# Train loss: 0.004798  [ 1000/ 4500]
# Train loss: 0.006208  [ 1500/ 4500]
# Train loss: 0.005411  [ 2000/ 4500]
# Train loss: 0.005368  [ 2500/ 4500]
# Train loss: 0.004343  [ 3000/ 4500]
# Train loss: 0.005118  [ 3500/ 4500]
# Train loss: 0.005073  [ 4000/ 4500]
# Test Loss:  0.012305
#
# Epoch 42
# -------------------------------
# Train loss: 0.004261  [    0/ 4500]
# Train loss: 0.004785  [  500/ 4500]
# Train loss: 0.004795  [ 1000/ 4500]
# Train loss: 0.006187  [ 1500/ 4500]
# Train loss: 0.005409  [ 2000/ 4500]
# Train loss: 0.005336  [ 2500/ 4500]
# Train loss: 0.004327  [ 3000/ 4500]
# Train loss: 0.005073  [ 3500/ 4500]
# Train loss: 0.005078  [ 4000/ 4500]
# Test Loss:  0.012321
#
# Epoch 43
# -------------------------------
# Train loss: 0.004278  [    0/ 4500]
# Train loss: 0.004795  [  500/ 4500]
# Train loss: 0.004799  [ 1000/ 4500]
# Train loss: 0.006169  [ 1500/ 4500]
# Train loss: 0.005405  [ 2000/ 4500]
# Train loss: 0.005306  [ 2500/ 4500]
# Train loss: 0.004313  [ 3000/ 4500]
# Train loss: 0.005030  [ 3500/ 4500]
# Train loss: 0.005080  [ 4000/ 4500]
# Test Loss:  0.012336
#
# Epoch 44
# -------------------------------
# Train loss: 0.004305  [    0/ 4500]
# Train loss: 0.004809  [  500/ 4500]
# Train loss: 0.004805  [ 1000/ 4500]
# Train loss: 0.006155  [ 1500/ 4500]
# Train loss: 0.005401  [ 2000/ 4500]
# Train loss: 0.005278  [ 2500/ 4500]
# Train loss: 0.004299  [ 3000/ 4500]
# Train loss: 0.004990  [ 3500/ 4500]
# Train loss: 0.005082  [ 4000/ 4500]
# Test Loss:  0.012346
#
# Epoch 45
# -------------------------------
# Train loss: 0.004338  [    0/ 4500]
# Train loss: 0.004826  [  500/ 4500]
# Train loss: 0.004812  [ 1000/ 4500]
# Train loss: 0.006141  [ 1500/ 4500]
# Train loss: 0.005398  [ 2000/ 4500]
# Train loss: 0.005254  [ 2500/ 4500]
# Train loss: 0.004285  [ 3000/ 4500]
# Train loss: 0.004952  [ 3500/ 4500]
# Train loss: 0.005081  [ 4000/ 4500]
# Test Loss:  0.012350
#
# Epoch 46
# -------------------------------
# Train loss: 0.004376  [    0/ 4500]
# Train loss: 0.004844  [  500/ 4500]
# Train loss: 0.004821  [ 1000/ 4500]
# Train loss: 0.006124  [ 1500/ 4500]
# Train loss: 0.005398  [ 2000/ 4500]
# Train loss: 0.005232  [ 2500/ 4500]
# Train loss: 0.004268  [ 3000/ 4500]
# Train loss: 0.004916  [ 3500/ 4500]
# Train loss: 0.005078  [ 4000/ 4500]
# Test Loss:  0.012345
#
# Epoch 47
# -------------------------------
# Train loss: 0.004414  [    0/ 4500]
# Train loss: 0.004860  [  500/ 4500]
# Train loss: 0.004829  [ 1000/ 4500]
# Train loss: 0.006104  [ 1500/ 4500]
# Train loss: 0.005402  [ 2000/ 4500]
# Train loss: 0.005207  [ 2500/ 4500]
# Train loss: 0.004252  [ 3000/ 4500]
# Train loss: 0.004882  [ 3500/ 4500]
# Train loss: 0.005073  [ 4000/ 4500]
# Test Loss:  0.012331
#
# Epoch 48
# -------------------------------
# Train loss: 0.004453  [    0/ 4500]
# Train loss: 0.004869  [  500/ 4500]
# Train loss: 0.004835  [ 1000/ 4500]
# Train loss: 0.006081  [ 1500/ 4500]
# Train loss: 0.005410  [ 2000/ 4500]
# Train loss: 0.005176  [ 2500/ 4500]
# Train loss: 0.004236  [ 3000/ 4500]
# Train loss: 0.004852  [ 3500/ 4500]
# Train loss: 0.005068  [ 4000/ 4500]
# Test Loss:  0.012308
#
# Epoch 49
# -------------------------------
# Train loss: 0.004489  [    0/ 4500]
# Train loss: 0.004868  [  500/ 4500]
# Train loss: 0.004838  [ 1000/ 4500]
# Train loss: 0.006056  [ 1500/ 4500]
# Train loss: 0.005424  [ 2000/ 4500]
# Train loss: 0.005137  [ 2500/ 4500]
# Train loss: 0.004223  [ 3000/ 4500]
# Train loss: 0.004827  [ 3500/ 4500]
# Train loss: 0.005067  [ 4000/ 4500]
# Test Loss:  0.012280
#
# Epoch 50
# -------------------------------
# Train loss: 0.004524  [    0/ 4500]
# Train loss: 0.004854  [  500/ 4500]
# Train loss: 0.004837  [ 1000/ 4500]
# Train loss: 0.006031  [ 1500/ 4500]
# Train loss: 0.005442  [ 2000/ 4500]
# Train loss: 0.005091  [ 2500/ 4500]
# Train loss: 0.004212  [ 3000/ 4500]
# Train loss: 0.004807  [ 3500/ 4500]
# Train loss: 0.005074  [ 4000/ 4500]
# Test Loss:  0.012253
#
# Epoch 51
# -------------------------------
# Train loss: 0.004559  [    0/ 4500]
# Train loss: 0.004831  [  500/ 4500]
# Train loss: 0.004830  [ 1000/ 4500]
# Train loss: 0.006007  [ 1500/ 4500]
# Train loss: 0.005462  [ 2000/ 4500]
# Train loss: 0.005043  [ 2500/ 4500]
# Train loss: 0.004204  [ 3000/ 4500]
# Train loss: 0.004790  [ 3500/ 4500]
# Train loss: 0.005088  [ 4000/ 4500]
# Test Loss:  0.012231
#
# Epoch 52
# -------------------------------
# Train loss: 0.004598  [    0/ 4500]
# Train loss: 0.004805  [  500/ 4500]
# Train loss: 0.004821  [ 1000/ 4500]
# Train loss: 0.005984  [ 1500/ 4500]
# Train loss: 0.005485  [ 2000/ 4500]
# Train loss: 0.004996  [ 2500/ 4500]
# Train loss: 0.004196  [ 3000/ 4500]
# Train loss: 0.004776  [ 3500/ 4500]
# Train loss: 0.005109  [ 4000/ 4500]
# Test Loss:  0.012217
#
# Epoch 53
# -------------------------------
# Train loss: 0.004639  [    0/ 4500]
# Train loss: 0.004781  [  500/ 4500]
# Train loss: 0.004811  [ 1000/ 4500]
# Train loss: 0.005960  [ 1500/ 4500]
# Train loss: 0.005509  [ 2000/ 4500]
# Train loss: 0.004952  [ 2500/ 4500]
# Train loss: 0.004189  [ 3000/ 4500]
# Train loss: 0.004762  [ 3500/ 4500]
# Train loss: 0.005136  [ 4000/ 4500]
# Test Loss:  0.012211
#
# Epoch 54
# -------------------------------
# Train loss: 0.004682  [    0/ 4500]
# Train loss: 0.004762  [  500/ 4500]
# Train loss: 0.004802  [ 1000/ 4500]
# Train loss: 0.005935  [ 1500/ 4500]
# Train loss: 0.005534  [ 2000/ 4500]
# Train loss: 0.004912  [ 2500/ 4500]
# Train loss: 0.004180  [ 3000/ 4500]
# Train loss: 0.004747  [ 3500/ 4500]
# Train loss: 0.005168  [ 4000/ 4500]
# Test Loss:  0.012212
#
# Epoch 55
# -------------------------------
# Train loss: 0.004723  [    0/ 4500]
# Train loss: 0.004754  [  500/ 4500]
# Train loss: 0.004796  [ 1000/ 4500]
# Train loss: 0.005909  [ 1500/ 4500]
# Train loss: 0.005562  [ 2000/ 4500]
# Train loss: 0.004874  [ 2500/ 4500]
# Train loss: 0.004171  [ 3000/ 4500]
# Train loss: 0.004732  [ 3500/ 4500]
# Train loss: 0.005202  [ 4000/ 4500]
# Test Loss:  0.012218
#
# Epoch 56
# -------------------------------
# Train loss: 0.004757  [    0/ 4500]
# Train loss: 0.004757  [  500/ 4500]
# Train loss: 0.004793  [ 1000/ 4500]
# Train loss: 0.005880  [ 1500/ 4500]
# Train loss: 0.005591  [ 2000/ 4500]
# Train loss: 0.004840  [ 2500/ 4500]
# Train loss: 0.004159  [ 3000/ 4500]
# Train loss: 0.004717  [ 3500/ 4500]
# Train loss: 0.005237  [ 4000/ 4500]
# Test Loss:  0.012225
#
# Epoch 57
# -------------------------------
# Train loss: 0.004782  [    0/ 4500]
# Train loss: 0.004771  [  500/ 4500]
# Train loss: 0.004792  [ 1000/ 4500]
# Train loss: 0.005850  [ 1500/ 4500]
# Train loss: 0.005620  [ 2000/ 4500]
# Train loss: 0.004811  [ 2500/ 4500]
# Train loss: 0.004144  [ 3000/ 4500]
# Train loss: 0.004703  [ 3500/ 4500]
# Train loss: 0.005273  [ 4000/ 4500]
# Test Loss:  0.012232
#
# Epoch 58
# -------------------------------
# Train loss: 0.004794  [    0/ 4500]
# Train loss: 0.004795  [  500/ 4500]
# Train loss: 0.004792  [ 1000/ 4500]
# Train loss: 0.005820  [ 1500/ 4500]
# Train loss: 0.005647  [ 2000/ 4500]
# Train loss: 0.004786  [ 2500/ 4500]
# Train loss: 0.004123  [ 3000/ 4500]
# Train loss: 0.004689  [ 3500/ 4500]
# Train loss: 0.005305  [ 4000/ 4500]
# Test Loss:  0.012235
#
# Epoch 59
# -------------------------------
# Train loss: 0.004789  [    0/ 4500]
# Train loss: 0.004827  [  500/ 4500]
# Train loss: 0.004791  [ 1000/ 4500]
# Train loss: 0.005790  [ 1500/ 4500]
# Train loss: 0.005668  [ 2000/ 4500]
# Train loss: 0.004767  [ 2500/ 4500]
# Train loss: 0.004098  [ 3000/ 4500]
# Train loss: 0.004677  [ 3500/ 4500]
# Train loss: 0.005330  [ 4000/ 4500]
# Test Loss:  0.012231
#
# Epoch 60
# -------------------------------
# Train loss: 0.004766  [    0/ 4500]
# Train loss: 0.004866  [  500/ 4500]
# Train loss: 0.004787  [ 1000/ 4500]
# Train loss: 0.005761  [ 1500/ 4500]
# Train loss: 0.005682  [ 2000/ 4500]
# Train loss: 0.004752  [ 2500/ 4500]
# Train loss: 0.004069  [ 3000/ 4500]
# Train loss: 0.004666  [ 3500/ 4500]
# Train loss: 0.005345  [ 4000/ 4500]
# Test Loss:  0.012219
#
# Epoch 61
# -------------------------------
# Train loss: 0.004725  [    0/ 4500]
# Train loss: 0.004910  [  500/ 4500]
# Train loss: 0.004777  [ 1000/ 4500]
# Train loss: 0.005731  [ 1500/ 4500]
# Train loss: 0.005690  [ 2000/ 4500]
# Train loss: 0.004741  [ 2500/ 4500]
# Train loss: 0.004040  [ 3000/ 4500]
# Train loss: 0.004655  [ 3500/ 4500]
# Train loss: 0.005348  [ 4000/ 4500]
# Test Loss:  0.012200
#
# Epoch 62
# -------------------------------
# Train loss: 0.004670  [    0/ 4500]
# Train loss: 0.004954  [  500/ 4500]
# Train loss: 0.004760  [ 1000/ 4500]
# Train loss: 0.005701  [ 1500/ 4500]
# Train loss: 0.005693  [ 2000/ 4500]
# Train loss: 0.004733  [ 2500/ 4500]
# Train loss: 0.004012  [ 3000/ 4500]
# Train loss: 0.004644  [ 3500/ 4500]
# Train loss: 0.005338  [ 4000/ 4500]
# Test Loss:  0.012176
#
# Epoch 63
# -------------------------------
# Train loss: 0.004606  [    0/ 4500]
# Train loss: 0.004997  [  500/ 4500]
# Train loss: 0.004734  [ 1000/ 4500]
# Train loss: 0.005668  [ 1500/ 4500]
# Train loss: 0.005694  [ 2000/ 4500]
# Train loss: 0.004726  [ 2500/ 4500]
# Train loss: 0.003984  [ 3000/ 4500]
# Train loss: 0.004632  [ 3500/ 4500]
# Train loss: 0.005316  [ 4000/ 4500]
# Test Loss:  0.012150
#
# Epoch 64
# -------------------------------
# Train loss: 0.004536  [    0/ 4500]
# Train loss: 0.005035  [  500/ 4500]
# Train loss: 0.004699  [ 1000/ 4500]
# Train loss: 0.005635  [ 1500/ 4500]
# Train loss: 0.005695  [ 2000/ 4500]
# Train loss: 0.004720  [ 2500/ 4500]
# Train loss: 0.003959  [ 3000/ 4500]
# Train loss: 0.004618  [ 3500/ 4500]
# Train loss: 0.005284  [ 4000/ 4500]
# Test Loss:  0.012122
#
# Epoch 65
# -------------------------------
# Train loss: 0.004466  [    0/ 4500]
# Train loss: 0.005065  [  500/ 4500]
# Train loss: 0.004657  [ 1000/ 4500]
# Train loss: 0.005600  [ 1500/ 4500]
# Train loss: 0.005696  [ 2000/ 4500]
# Train loss: 0.004716  [ 2500/ 4500]
# Train loss: 0.003934  [ 3000/ 4500]
# Train loss: 0.004602  [ 3500/ 4500]
# Train loss: 0.005243  [ 4000/ 4500]
# Test Loss:  0.012094
#
# Epoch 66
# -------------------------------
# Train loss: 0.004396  [    0/ 4500]
# Train loss: 0.005087  [  500/ 4500]
# Train loss: 0.004610  [ 1000/ 4500]
# Train loss: 0.005566  [ 1500/ 4500]
# Train loss: 0.005696  [ 2000/ 4500]
# Train loss: 0.004712  [ 2500/ 4500]
# Train loss: 0.003909  [ 3000/ 4500]
# Train loss: 0.004584  [ 3500/ 4500]
# Train loss: 0.005195  [ 4000/ 4500]
# Test Loss:  0.012067
#
# Epoch 67
# -------------------------------
# Train loss: 0.004329  [    0/ 4500]
# Train loss: 0.005099  [  500/ 4500]
# Train loss: 0.004559  [ 1000/ 4500]
# Train loss: 0.005531  [ 1500/ 4500]
# Train loss: 0.005695  [ 2000/ 4500]
# Train loss: 0.004710  [ 2500/ 4500]
# Train loss: 0.003884  [ 3000/ 4500]
# Train loss: 0.004565  [ 3500/ 4500]
# Train loss: 0.005142  [ 4000/ 4500]
# Test Loss:  0.012041
#
# Epoch 68
# -------------------------------
# Train loss: 0.004266  [    0/ 4500]
# Train loss: 0.005102  [  500/ 4500]
# Train loss: 0.004508  [ 1000/ 4500]
# Train loss: 0.005498  [ 1500/ 4500]
# Train loss: 0.005688  [ 2000/ 4500]
# Train loss: 0.004708  [ 2500/ 4500]
# Train loss: 0.003859  [ 3000/ 4500]
# Train loss: 0.004545  [ 3500/ 4500]
# Train loss: 0.005083  [ 4000/ 4500]
# Test Loss:  0.012016
#
# Epoch 69
# -------------------------------
# Train loss: 0.004207  [    0/ 4500]
# Train loss: 0.005097  [  500/ 4500]
# Train loss: 0.004456  [ 1000/ 4500]
# Train loss: 0.005464  [ 1500/ 4500]
# Train loss: 0.005676  [ 2000/ 4500]
# Train loss: 0.004707  [ 2500/ 4500]
# Train loss: 0.003834  [ 3000/ 4500]
# Train loss: 0.004524  [ 3500/ 4500]
# Train loss: 0.005022  [ 4000/ 4500]
# Test Loss:  0.011992
#
# Epoch 70
# -------------------------------
# Train loss: 0.004152  [    0/ 4500]
# Train loss: 0.005084  [  500/ 4500]
# Train loss: 0.004405  [ 1000/ 4500]
# Train loss: 0.005431  [ 1500/ 4500]
# Train loss: 0.005658  [ 2000/ 4500]
# Train loss: 0.004704  [ 2500/ 4500]
# Train loss: 0.003809  [ 3000/ 4500]
# Train loss: 0.004503  [ 3500/ 4500]
# Train loss: 0.004959  [ 4000/ 4500]
# Test Loss:  0.011970
#
# Epoch 71
# -------------------------------
# Train loss: 0.004102  [    0/ 4500]
# Train loss: 0.005066  [  500/ 4500]
# Train loss: 0.004357  [ 1000/ 4500]
# Train loss: 0.005398  [ 1500/ 4500]
# Train loss: 0.005633  [ 2000/ 4500]
# Train loss: 0.004699  [ 2500/ 4500]
# Train loss: 0.003784  [ 3000/ 4500]
# Train loss: 0.004482  [ 3500/ 4500]
# Train loss: 0.004895  [ 4000/ 4500]
# Test Loss:  0.011948
#
# Epoch 72
# -------------------------------
# Train loss: 0.004055  [    0/ 4500]
# Train loss: 0.005042  [  500/ 4500]
# Train loss: 0.004310  [ 1000/ 4500]
# Train loss: 0.005366  [ 1500/ 4500]
# Train loss: 0.005602  [ 2000/ 4500]
# Train loss: 0.004691  [ 2500/ 4500]
# Train loss: 0.003759  [ 3000/ 4500]
# Train loss: 0.004460  [ 3500/ 4500]
# Train loss: 0.004830  [ 4000/ 4500]
# Test Loss:  0.011927
#
# Epoch 73
# -------------------------------
# Train loss: 0.004012  [    0/ 4500]
# Train loss: 0.005016  [  500/ 4500]
# Train loss: 0.004266  [ 1000/ 4500]
# Train loss: 0.005334  [ 1500/ 4500]
# Train loss: 0.005566  [ 2000/ 4500]
# Train loss: 0.004679  [ 2500/ 4500]
# Train loss: 0.003733  [ 3000/ 4500]
# Train loss: 0.004437  [ 3500/ 4500]
# Train loss: 0.004765  [ 4000/ 4500]
# Test Loss:  0.011907
#
# Epoch 74
# -------------------------------
# Train loss: 0.003971  [    0/ 4500]
# Train loss: 0.004986  [  500/ 4500]
# Train loss: 0.004222  [ 1000/ 4500]
# Train loss: 0.005301  [ 1500/ 4500]
# Train loss: 0.005526  [ 2000/ 4500]
# Train loss: 0.004663  [ 2500/ 4500]
# Train loss: 0.003708  [ 3000/ 4500]
# Train loss: 0.004415  [ 3500/ 4500]
# Train loss: 0.004701  [ 4000/ 4500]
# Test Loss:  0.011887
#
# Epoch 75
# -------------------------------
# Train loss: 0.003933  [    0/ 4500]
# Train loss: 0.004955  [  500/ 4500]
# Train loss: 0.004181  [ 1000/ 4500]
# Train loss: 0.005269  [ 1500/ 4500]
# Train loss: 0.005482  [ 2000/ 4500]
# Train loss: 0.004643  [ 2500/ 4500]
# Train loss: 0.003682  [ 3000/ 4500]
# Train loss: 0.004391  [ 3500/ 4500]
# Train loss: 0.004637  [ 4000/ 4500]
# Test Loss:  0.011867
#
# Epoch 76
# -------------------------------
# Train loss: 0.003897  [    0/ 4500]
# Train loss: 0.004923  [  500/ 4500]
# Train loss: 0.004140  [ 1000/ 4500]
# Train loss: 0.005236  [ 1500/ 4500]
# Train loss: 0.005435  [ 2000/ 4500]
# Train loss: 0.004619  [ 2500/ 4500]
# Train loss: 0.003656  [ 3000/ 4500]
# Train loss: 0.004365  [ 3500/ 4500]
# Train loss: 0.004575  [ 4000/ 4500]
# Test Loss:  0.011848
#
# Epoch 77
# -------------------------------
# Train loss: 0.003862  [    0/ 4500]
# Train loss: 0.004891  [  500/ 4500]
# Train loss: 0.004100  [ 1000/ 4500]
# Train loss: 0.005203  [ 1500/ 4500]
# Train loss: 0.005386  [ 2000/ 4500]
# Train loss: 0.004592  [ 2500/ 4500]
# Train loss: 0.003629  [ 3000/ 4500]
# Train loss: 0.004339  [ 3500/ 4500]
# Train loss: 0.004514  [ 4000/ 4500]
# Test Loss:  0.011829
#
# Epoch 78
# -------------------------------
# Train loss: 0.003828  [    0/ 4500]
# Train loss: 0.004857  [  500/ 4500]
# Train loss: 0.004060  [ 1000/ 4500]
# Train loss: 0.005170  [ 1500/ 4500]
# Train loss: 0.005336  [ 2000/ 4500]
# Train loss: 0.004563  [ 2500/ 4500]
# Train loss: 0.003602  [ 3000/ 4500]
# Train loss: 0.004312  [ 3500/ 4500]
# Train loss: 0.004454  [ 4000/ 4500]
# Test Loss:  0.011810
#
# Epoch 79
# -------------------------------
# Train loss: 0.003795  [    0/ 4500]
# Train loss: 0.004824  [  500/ 4500]
# Train loss: 0.004022  [ 1000/ 4500]
# Train loss: 0.005137  [ 1500/ 4500]
# Train loss: 0.005286  [ 2000/ 4500]
# Train loss: 0.004532  [ 2500/ 4500]
# Train loss: 0.003575  [ 3000/ 4500]
# Train loss: 0.004283  [ 3500/ 4500]
# Train loss: 0.004396  [ 4000/ 4500]
# Test Loss:  0.011791
#
# Epoch 80
# -------------------------------
# Train loss: 0.003763  [    0/ 4500]
# Train loss: 0.004790  [  500/ 4500]
# Train loss: 0.003984  [ 1000/ 4500]
# Train loss: 0.005103  [ 1500/ 4500]
# Train loss: 0.005234  [ 2000/ 4500]
# Train loss: 0.004498  [ 2500/ 4500]
# Train loss: 0.003548  [ 3000/ 4500]
# Train loss: 0.004254  [ 3500/ 4500]
# Train loss: 0.004340  [ 4000/ 4500]
# Test Loss:  0.011772
#
# Epoch 81
# -------------------------------
# Train loss: 0.003731  [    0/ 4500]
# Train loss: 0.004756  [  500/ 4500]
# Train loss: 0.003947  [ 1000/ 4500]
# Train loss: 0.005069  [ 1500/ 4500]
# Train loss: 0.005184  [ 2000/ 4500]
# Train loss: 0.004463  [ 2500/ 4500]
# Train loss: 0.003520  [ 3000/ 4500]
# Train loss: 0.004223  [ 3500/ 4500]
# Train loss: 0.004285  [ 4000/ 4500]
# Test Loss:  0.011754
#
# Epoch 82
# -------------------------------
# Train loss: 0.003699  [    0/ 4500]
# Train loss: 0.004721  [  500/ 4500]
# Train loss: 0.003910  [ 1000/ 4500]
# Train loss: 0.005035  [ 1500/ 4500]
# Train loss: 0.005132  [ 2000/ 4500]
# Train loss: 0.004427  [ 2500/ 4500]
# Train loss: 0.003493  [ 3000/ 4500]
# Train loss: 0.004192  [ 3500/ 4500]
# Train loss: 0.004231  [ 4000/ 4500]
# Test Loss:  0.011735
#
# Epoch 83
# -------------------------------
# Train loss: 0.003667  [    0/ 4500]
# Train loss: 0.004686  [  500/ 4500]
# Train loss: 0.003874  [ 1000/ 4500]
# Train loss: 0.005000  [ 1500/ 4500]
# Train loss: 0.005082  [ 2000/ 4500]
# Train loss: 0.004391  [ 2500/ 4500]
# Train loss: 0.003465  [ 3000/ 4500]
# Train loss: 0.004160  [ 3500/ 4500]
# Train loss: 0.004178  [ 4000/ 4500]
# Test Loss:  0.011717
#
# Epoch 84
# -------------------------------
# Train loss: 0.003636  [    0/ 4500]
# Train loss: 0.004652  [  500/ 4500]
# Train loss: 0.003839  [ 1000/ 4500]
# Train loss: 0.004966  [ 1500/ 4500]
# Train loss: 0.005031  [ 2000/ 4500]
# Train loss: 0.004353  [ 2500/ 4500]
# Train loss: 0.003437  [ 3000/ 4500]
# Train loss: 0.004128  [ 3500/ 4500]
# Train loss: 0.004127  [ 4000/ 4500]
# Test Loss:  0.011699
#
# Epoch 85
# -------------------------------
# Train loss: 0.003605  [    0/ 4500]
# Train loss: 0.004616  [  500/ 4500]
# Train loss: 0.003803  [ 1000/ 4500]
# Train loss: 0.004931  [ 1500/ 4500]
# Train loss: 0.004981  [ 2000/ 4500]
# Train loss: 0.004315  [ 2500/ 4500]
# Train loss: 0.003409  [ 3000/ 4500]
# Train loss: 0.004096  [ 3500/ 4500]
# Train loss: 0.004077  [ 4000/ 4500]
# Test Loss:  0.011680
#
# Epoch 86
# -------------------------------
# Train loss: 0.003573  [    0/ 4500]
# Train loss: 0.004581  [  500/ 4500]
# Train loss: 0.003769  [ 1000/ 4500]
# Train loss: 0.004896  [ 1500/ 4500]
# Train loss: 0.004932  [ 2000/ 4500]
# Train loss: 0.004276  [ 2500/ 4500]
# Train loss: 0.003382  [ 3000/ 4500]
# Train loss: 0.004063  [ 3500/ 4500]
# Train loss: 0.004028  [ 4000/ 4500]
# Test Loss:  0.011661
#
# Epoch 87
# -------------------------------
# Train loss: 0.003542  [    0/ 4500]
# Train loss: 0.004545  [  500/ 4500]
# Train loss: 0.003734  [ 1000/ 4500]
# Train loss: 0.004861  [ 1500/ 4500]
# Train loss: 0.004883  [ 2000/ 4500]
# Train loss: 0.004238  [ 2500/ 4500]
# Train loss: 0.003354  [ 3000/ 4500]
# Train loss: 0.004030  [ 3500/ 4500]
# Train loss: 0.003980  [ 4000/ 4500]
# Test Loss:  0.011643
#
# Epoch 88
# -------------------------------
# Train loss: 0.003511  [    0/ 4500]
# Train loss: 0.004510  [  500/ 4500]
# Train loss: 0.003701  [ 1000/ 4500]
# Train loss: 0.004826  [ 1500/ 4500]
# Train loss: 0.004834  [ 2000/ 4500]
# Train loss: 0.004198  [ 2500/ 4500]
# Train loss: 0.003326  [ 3000/ 4500]
# Train loss: 0.003997  [ 3500/ 4500]
# Train loss: 0.003933  [ 4000/ 4500]
# Test Loss:  0.011625
#
# Epoch 89
# -------------------------------
# Train loss: 0.003480  [    0/ 4500]
# Train loss: 0.004474  [  500/ 4500]
# Train loss: 0.003667  [ 1000/ 4500]
# Train loss: 0.004791  [ 1500/ 4500]
# Train loss: 0.004786  [ 2000/ 4500]
# Train loss: 0.004159  [ 2500/ 4500]
# Train loss: 0.003299  [ 3000/ 4500]
# Train loss: 0.003964  [ 3500/ 4500]
# Train loss: 0.003886  [ 4000/ 4500]
# Test Loss:  0.011607
#
# Epoch 90
# -------------------------------
# Train loss: 0.003449  [    0/ 4500]
# Train loss: 0.004438  [  500/ 4500]
# Train loss: 0.003634  [ 1000/ 4500]
# Train loss: 0.004756  [ 1500/ 4500]
# Train loss: 0.004738  [ 2000/ 4500]
# Train loss: 0.004120  [ 2500/ 4500]
# Train loss: 0.003272  [ 3000/ 4500]
# Train loss: 0.003932  [ 3500/ 4500]
# Train loss: 0.003840  [ 4000/ 4500]
# Test Loss:  0.011588
#
# Epoch 91
# -------------------------------
# Train loss: 0.003419  [    0/ 4500]
# Train loss: 0.004402  [  500/ 4500]
# Train loss: 0.003601  [ 1000/ 4500]
# Train loss: 0.004722  [ 1500/ 4500]
# Train loss: 0.004691  [ 2000/ 4500]
# Train loss: 0.004080  [ 2500/ 4500]
# Train loss: 0.003245  [ 3000/ 4500]
# Train loss: 0.003898  [ 3500/ 4500]
# Train loss: 0.003795  [ 4000/ 4500]
# Test Loss:  0.011571
#
# Epoch 92
# -------------------------------
# Train loss: 0.003389  [    0/ 4500]
# Train loss: 0.004367  [  500/ 4500]
# Train loss: 0.003569  [ 1000/ 4500]
# Train loss: 0.004686  [ 1500/ 4500]
# Train loss: 0.004644  [ 2000/ 4500]
# Train loss: 0.004041  [ 2500/ 4500]
# Train loss: 0.003218  [ 3000/ 4500]
# Train loss: 0.003866  [ 3500/ 4500]
# Train loss: 0.003751  [ 4000/ 4500]
# Test Loss:  0.011553
#
# Epoch 93
# -------------------------------
# Train loss: 0.003359  [    0/ 4500]
# Train loss: 0.004331  [  500/ 4500]
# Train loss: 0.003536  [ 1000/ 4500]
# Train loss: 0.004651  [ 1500/ 4500]
# Train loss: 0.004598  [ 2000/ 4500]
# Train loss: 0.004001  [ 2500/ 4500]
# Train loss: 0.003191  [ 3000/ 4500]
# Train loss: 0.003833  [ 3500/ 4500]
# Train loss: 0.003708  [ 4000/ 4500]
# Test Loss:  0.011535
#
# Epoch 94
# -------------------------------
# Train loss: 0.003329  [    0/ 4500]
# Train loss: 0.004296  [  500/ 4500]
# Train loss: 0.003505  [ 1000/ 4500]
# Train loss: 0.004616  [ 1500/ 4500]
# Train loss: 0.004552  [ 2000/ 4500]
# Train loss: 0.003962  [ 2500/ 4500]
# Train loss: 0.003164  [ 3000/ 4500]
# Train loss: 0.003801  [ 3500/ 4500]
# Train loss: 0.003665  [ 4000/ 4500]
# Test Loss:  0.011517
#
# Epoch 95
# -------------------------------
# Train loss: 0.003299  [    0/ 4500]
# Train loss: 0.004260  [  500/ 4500]
# Train loss: 0.003473  [ 1000/ 4500]
# Train loss: 0.004582  [ 1500/ 4500]
# Train loss: 0.004506  [ 2000/ 4500]
# Train loss: 0.003923  [ 2500/ 4500]
# Train loss: 0.003138  [ 3000/ 4500]
# Train loss: 0.003768  [ 3500/ 4500]
# Train loss: 0.003623  [ 4000/ 4500]
# Test Loss:  0.011500
#
# Epoch 96
# -------------------------------
# Train loss: 0.003270  [    0/ 4500]
# Train loss: 0.004224  [  500/ 4500]
# Train loss: 0.003442  [ 1000/ 4500]
# Train loss: 0.004547  [ 1500/ 4500]
# Train loss: 0.004461  [ 2000/ 4500]
# Train loss: 0.003883  [ 2500/ 4500]
# Train loss: 0.003111  [ 3000/ 4500]
# Train loss: 0.003736  [ 3500/ 4500]
# Train loss: 0.003582  [ 4000/ 4500]
# Test Loss:  0.011482
#
# Epoch 97
# -------------------------------
# Train loss: 0.003240  [    0/ 4500]
# Train loss: 0.004188  [  500/ 4500]
# Train loss: 0.003411  [ 1000/ 4500]
# Train loss: 0.004512  [ 1500/ 4500]
# Train loss: 0.004416  [ 2000/ 4500]
# Train loss: 0.003844  [ 2500/ 4500]
# Train loss: 0.003085  [ 3000/ 4500]
# Train loss: 0.003704  [ 3500/ 4500]
# Train loss: 0.003541  [ 4000/ 4500]
# Test Loss:  0.011465
#
# Epoch 98
# -------------------------------
# Train loss: 0.003211  [    0/ 4500]
# Train loss: 0.004153  [  500/ 4500]
# Train loss: 0.003380  [ 1000/ 4500]
# Train loss: 0.004477  [ 1500/ 4500]
# Train loss: 0.004371  [ 2000/ 4500]
# Train loss: 0.003805  [ 2500/ 4500]
# Train loss: 0.003059  [ 3000/ 4500]
# Train loss: 0.003672  [ 3500/ 4500]
# Train loss: 0.003501  [ 4000/ 4500]
# Test Loss:  0.011448
#
# Epoch 99
# -------------------------------
# Train loss: 0.003182  [    0/ 4500]
# Train loss: 0.004117  [  500/ 4500]
# Train loss: 0.003350  [ 1000/ 4500]
# Train loss: 0.004443  [ 1500/ 4500]
# Train loss: 0.004327  [ 2000/ 4500]
# Train loss: 0.003767  [ 2500/ 4500]
# Train loss: 0.003033  [ 3000/ 4500]
# Train loss: 0.003640  [ 3500/ 4500]
# Train loss: 0.003462  [ 4000/ 4500]
# Test Loss:  0.011432
#
# Epoch 100
# -------------------------------
# Train loss: 0.003153  [    0/ 4500]
# Train loss: 0.004081  [  500/ 4500]
# Train loss: 0.003320  [ 1000/ 4500]
# Train loss: 0.004409  [ 1500/ 4500]
# Train loss: 0.004283  [ 2000/ 4500]
# Train loss: 0.003728  [ 2500/ 4500]
# Train loss: 0.003007  [ 3000/ 4500]
# Train loss: 0.003609  [ 3500/ 4500]
# Train loss: 0.003423  [ 4000/ 4500]
# Test Loss:  0.011415
#
# Epoch 101
# -------------------------------
# Train loss: 0.003125  [    0/ 4500]
# Train loss: 0.004046  [  500/ 4500]
# Train loss: 0.003290  [ 1000/ 4500]
# Train loss: 0.004374  [ 1500/ 4500]
# Train loss: 0.004240  [ 2000/ 4500]
# Train loss: 0.003690  [ 2500/ 4500]
# Train loss: 0.002982  [ 3000/ 4500]
# Train loss: 0.003577  [ 3500/ 4500]
# Train loss: 0.003385  [ 4000/ 4500]
# Test Loss:  0.011398
#
# Epoch 102
# -------------------------------
# Train loss: 0.003097  [    0/ 4500]
# Train loss: 0.004010  [  500/ 4500]
# Train loss: 0.003260  [ 1000/ 4500]
# Train loss: 0.004340  [ 1500/ 4500]
# Train loss: 0.004197  [ 2000/ 4500]
# Train loss: 0.003652  [ 2500/ 4500]
# Train loss: 0.002957  [ 3000/ 4500]
# Train loss: 0.003546  [ 3500/ 4500]
# Train loss: 0.003348  [ 4000/ 4500]
# Test Loss:  0.011382
#
# Epoch 103
# -------------------------------
# Train loss: 0.003068  [    0/ 4500]
# Train loss: 0.003975  [  500/ 4500]
# Train loss: 0.003231  [ 1000/ 4500]
# Train loss: 0.004307  [ 1500/ 4500]
# Train loss: 0.004154  [ 2000/ 4500]
# Train loss: 0.003614  [ 2500/ 4500]
# Train loss: 0.002932  [ 3000/ 4500]
# Train loss: 0.003515  [ 3500/ 4500]
# Train loss: 0.003310  [ 4000/ 4500]
# Test Loss:  0.011365
#
# Epoch 104
# -------------------------------
# Train loss: 0.003041  [    0/ 4500]
# Train loss: 0.003939  [  500/ 4500]
# Train loss: 0.003202  [ 1000/ 4500]
# Train loss: 0.004273  [ 1500/ 4500]
# Train loss: 0.004112  [ 2000/ 4500]
# Train loss: 0.003577  [ 2500/ 4500]
# Train loss: 0.002907  [ 3000/ 4500]
# Train loss: 0.003485  [ 3500/ 4500]
# Train loss: 0.003274  [ 4000/ 4500]
# Test Loss:  0.011349
#
# Epoch 105
# -------------------------------
# Train loss: 0.003012  [    0/ 4500]
# Train loss: 0.003904  [  500/ 4500]
# Train loss: 0.003173  [ 1000/ 4500]
# Train loss: 0.004240  [ 1500/ 4500]
# Train loss: 0.004069  [ 2000/ 4500]
# Train loss: 0.003540  [ 2500/ 4500]
# Train loss: 0.002882  [ 3000/ 4500]
# Train loss: 0.003455  [ 3500/ 4500]
# Train loss: 0.003238  [ 4000/ 4500]
# Test Loss:  0.011333
#
# Epoch 106
# -------------------------------
# Train loss: 0.002985  [    0/ 4500]
# Train loss: 0.003868  [  500/ 4500]
# Train loss: 0.003145  [ 1000/ 4500]
# Train loss: 0.004206  [ 1500/ 4500]
# Train loss: 0.004028  [ 2000/ 4500]
# Train loss: 0.003503  [ 2500/ 4500]
# Train loss: 0.002858  [ 3000/ 4500]
# Train loss: 0.003425  [ 3500/ 4500]
# Train loss: 0.003202  [ 4000/ 4500]
# Test Loss:  0.011317
#
# Epoch 107
# -------------------------------
# Train loss: 0.002957  [    0/ 4500]
# Train loss: 0.003833  [  500/ 4500]
# Train loss: 0.003117  [ 1000/ 4500]
# Train loss: 0.004173  [ 1500/ 4500]
# Train loss: 0.003987  [ 2000/ 4500]
# Train loss: 0.003467  [ 2500/ 4500]
# Train loss: 0.002834  [ 3000/ 4500]
# Train loss: 0.003395  [ 3500/ 4500]
# Train loss: 0.003167  [ 4000/ 4500]
# Test Loss:  0.011301
#
# Epoch 108
# -------------------------------
# Train loss: 0.002930  [    0/ 4500]
# Train loss: 0.003797  [  500/ 4500]
# Train loss: 0.003089  [ 1000/ 4500]
# Train loss: 0.004140  [ 1500/ 4500]
# Train loss: 0.003946  [ 2000/ 4500]
# Train loss: 0.003431  [ 2500/ 4500]
# Train loss: 0.002810  [ 3000/ 4500]
# Train loss: 0.003366  [ 3500/ 4500]
# Train loss: 0.003133  [ 4000/ 4500]
# Test Loss:  0.011285
#
# Epoch 109
# -------------------------------
# Train loss: 0.002903  [    0/ 4500]
# Train loss: 0.003762  [  500/ 4500]
# Train loss: 0.003061  [ 1000/ 4500]
# Train loss: 0.004108  [ 1500/ 4500]
# Train loss: 0.003905  [ 2000/ 4500]
# Train loss: 0.003395  [ 2500/ 4500]
# Train loss: 0.002786  [ 3000/ 4500]
# Train loss: 0.003338  [ 3500/ 4500]
# Train loss: 0.003098  [ 4000/ 4500]
# Test Loss:  0.011270
#
# Epoch 110
# -------------------------------
# Train loss: 0.002876  [    0/ 4500]
# Train loss: 0.003727  [  500/ 4500]
# Train loss: 0.003034  [ 1000/ 4500]
# Train loss: 0.004075  [ 1500/ 4500]
# Train loss: 0.003865  [ 2000/ 4500]
# Train loss: 0.003359  [ 2500/ 4500]
# Train loss: 0.002762  [ 3000/ 4500]
# Train loss: 0.003309  [ 3500/ 4500]
# Train loss: 0.003065  [ 4000/ 4500]
# Test Loss:  0.011255
#
# Epoch 111
# -------------------------------
# Train loss: 0.002849  [    0/ 4500]
# Train loss: 0.003692  [  500/ 4500]
# Train loss: 0.003007  [ 1000/ 4500]
# Train loss: 0.004043  [ 1500/ 4500]
# Train loss: 0.003824  [ 2000/ 4500]
# Train loss: 0.003324  [ 2500/ 4500]
# Train loss: 0.002739  [ 3000/ 4500]
# Train loss: 0.003281  [ 3500/ 4500]
# Train loss: 0.003031  [ 4000/ 4500]
# Test Loss:  0.011239
#
# Epoch 112
# -------------------------------
# Train loss: 0.002822  [    0/ 4500]
# Train loss: 0.003657  [  500/ 4500]
# Train loss: 0.002980  [ 1000/ 4500]
# Train loss: 0.004011  [ 1500/ 4500]
# Train loss: 0.003785  [ 2000/ 4500]
# Train loss: 0.003289  [ 2500/ 4500]
# Train loss: 0.002716  [ 3000/ 4500]
# Train loss: 0.003254  [ 3500/ 4500]
# Train loss: 0.002998  [ 4000/ 4500]
# Test Loss:  0.011224
#
# Epoch 113
# -------------------------------
# Train loss: 0.002796  [    0/ 4500]
# Train loss: 0.003622  [  500/ 4500]
# Train loss: 0.002953  [ 1000/ 4500]
# Train loss: 0.003980  [ 1500/ 4500]
# Train loss: 0.003745  [ 2000/ 4500]
# Train loss: 0.003255  [ 2500/ 4500]
# Train loss: 0.002694  [ 3000/ 4500]
# Train loss: 0.003226  [ 3500/ 4500]
# Train loss: 0.002966  [ 4000/ 4500]
# Test Loss:  0.011209
#
# Epoch 114
# -------------------------------
# Train loss: 0.002769  [    0/ 4500]
# Train loss: 0.003587  [  500/ 4500]
# Train loss: 0.002927  [ 1000/ 4500]
# Train loss: 0.003948  [ 1500/ 4500]
# Train loss: 0.003707  [ 2000/ 4500]
# Train loss: 0.003221  [ 2500/ 4500]
# Train loss: 0.002671  [ 3000/ 4500]
# Train loss: 0.003200  [ 3500/ 4500]
# Train loss: 0.002934  [ 4000/ 4500]
# Test Loss:  0.011194
#
# Epoch 115
# -------------------------------
# Train loss: 0.002743  [    0/ 4500]
# Train loss: 0.003552  [  500/ 4500]
# Train loss: 0.002901  [ 1000/ 4500]
# Train loss: 0.003917  [ 1500/ 4500]
# Train loss: 0.003668  [ 2000/ 4500]
# Train loss: 0.003187  [ 2500/ 4500]
# Train loss: 0.002649  [ 3000/ 4500]
# Train loss: 0.003173  [ 3500/ 4500]
# Train loss: 0.002902  [ 4000/ 4500]
# Test Loss:  0.011180
#
# Epoch 116
# -------------------------------
# Train loss: 0.002718  [    0/ 4500]
# Train loss: 0.003517  [  500/ 4500]
# Train loss: 0.002875  [ 1000/ 4500]
# Train loss: 0.003886  [ 1500/ 4500]
# Train loss: 0.003630  [ 2000/ 4500]
# Train loss: 0.003154  [ 2500/ 4500]
# Train loss: 0.002627  [ 3000/ 4500]
# Train loss: 0.003147  [ 3500/ 4500]
# Train loss: 0.002871  [ 4000/ 4500]
# Test Loss:  0.011166
#
# Epoch 117
# -------------------------------
# Train loss: 0.002692  [    0/ 4500]
# Train loss: 0.003483  [  500/ 4500]
# Train loss: 0.002850  [ 1000/ 4500]
# Train loss: 0.003855  [ 1500/ 4500]
# Train loss: 0.003592  [ 2000/ 4500]
# Train loss: 0.003121  [ 2500/ 4500]
# Train loss: 0.002605  [ 3000/ 4500]
# Train loss: 0.003122  [ 3500/ 4500]
# Train loss: 0.002840  [ 4000/ 4500]
# Test Loss:  0.011152
#
# Epoch 118
# -------------------------------
# Train loss: 0.002667  [    0/ 4500]
# Train loss: 0.003448  [  500/ 4500]
# Train loss: 0.002825  [ 1000/ 4500]
# Train loss: 0.003824  [ 1500/ 4500]
# Train loss: 0.003554  [ 2000/ 4500]
# Train loss: 0.003089  [ 2500/ 4500]
# Train loss: 0.002583  [ 3000/ 4500]
# Train loss: 0.003096  [ 3500/ 4500]
# Train loss: 0.002809  [ 4000/ 4500]
# Test Loss:  0.011137
#
# Epoch 119
# -------------------------------
# Train loss: 0.002641  [    0/ 4500]
# Train loss: 0.003413  [  500/ 4500]
# Train loss: 0.002800  [ 1000/ 4500]
# Train loss: 0.003794  [ 1500/ 4500]
# Train loss: 0.003516  [ 2000/ 4500]
# Train loss: 0.003057  [ 2500/ 4500]
# Train loss: 0.002561  [ 3000/ 4500]
# Train loss: 0.003072  [ 3500/ 4500]
# Train loss: 0.002780  [ 4000/ 4500]
# Test Loss:  0.011123
#
# Epoch 120
# -------------------------------
# Train loss: 0.002616  [    0/ 4500]
# Train loss: 0.003378  [  500/ 4500]
# Train loss: 0.002775  [ 1000/ 4500]
# Train loss: 0.003764  [ 1500/ 4500]
# Train loss: 0.003479  [ 2000/ 4500]
# Train loss: 0.003025  [ 2500/ 4500]
# Train loss: 0.002540  [ 3000/ 4500]
# Train loss: 0.003047  [ 3500/ 4500]
# Train loss: 0.002750  [ 4000/ 4500]
# Test Loss:  0.011109
#
# Epoch 121
# -------------------------------
# Train loss: 0.002590  [    0/ 4500]
# Train loss: 0.003344  [  500/ 4500]
# Train loss: 0.002750  [ 1000/ 4500]
# Train loss: 0.003734  [ 1500/ 4500]
# Train loss: 0.003443  [ 2000/ 4500]
# Train loss: 0.002995  [ 2500/ 4500]
# Train loss: 0.002519  [ 3000/ 4500]
# Train loss: 0.003023  [ 3500/ 4500]
# Train loss: 0.002721  [ 4000/ 4500]
# Test Loss:  0.011095
#
# Epoch 122
# -------------------------------
# Train loss: 0.002565  [    0/ 4500]
# Train loss: 0.003310  [  500/ 4500]
# Train loss: 0.002726  [ 1000/ 4500]
# Train loss: 0.003704  [ 1500/ 4500]
# Train loss: 0.003407  [ 2000/ 4500]
# Train loss: 0.002964  [ 2500/ 4500]
# Train loss: 0.002498  [ 3000/ 4500]
# Train loss: 0.003000  [ 3500/ 4500]
# Train loss: 0.002692  [ 4000/ 4500]
# Test Loss:  0.011081
#
# Epoch 123
# -------------------------------
# Train loss: 0.002540  [    0/ 4500]
# Train loss: 0.003276  [  500/ 4500]
# Train loss: 0.002702  [ 1000/ 4500]
# Train loss: 0.003675  [ 1500/ 4500]
# Train loss: 0.003371  [ 2000/ 4500]
# Train loss: 0.002934  [ 2500/ 4500]
# Train loss: 0.002476  [ 3000/ 4500]
# Train loss: 0.002976  [ 3500/ 4500]
# Train loss: 0.002663  [ 4000/ 4500]
# Test Loss:  0.011068
#
# Epoch 124
# -------------------------------
# Train loss: 0.002515  [    0/ 4500]
# Train loss: 0.003242  [  500/ 4500]
# Train loss: 0.002678  [ 1000/ 4500]
# Train loss: 0.003645  [ 1500/ 4500]
# Train loss: 0.003335  [ 2000/ 4500]
# Train loss: 0.002904  [ 2500/ 4500]
# ...
# Test Loss:  0.010649
#
# Epoch 160
# -------------------------------
# Train loss: 0.001755  [    0/ 4500]
# Train loss: 0.002174  [  500/ 4500]
# Train loss: 0.001915  [ 1000/ 4500]
# Train loss: 0.002715  [ 1500/ 4500]
# Train loss: 0.002308  [ 2000/ 4500]
# Train loss: 0.002088  [ 2500/ 4500]
# Train loss: 0.001782  [ 3000/ 4500]
# Train loss: 0.002246  [ 3500/ 4500]
# Train loss: 0.001828  [ 4000/ 4500]
# Test Loss:  0.010639
#
# Epoch 161
# -------------------------------
# Train loss: 0.001738  [    0/ 4500]
# Train loss: 0.002149  [  500/ 4500]
# Train loss: 0.001896  [ 1000/ 4500]
# Train loss: 0.002692  [ 1500/ 4500]
# Train loss: 0.002285  [ 2000/ 4500]
# Train loss: 0.002070  [ 2500/ 4500]
# Train loss: 0.001765  [ 3000/ 4500]
# Train loss: 0.002228  [ 3500/ 4500]
# Train loss: 0.001809  [ 4000/ 4500]
# Test Loss:  0.010630
#
# Epoch 162
# -------------------------------
# Train loss: 0.001721  [    0/ 4500]
# Train loss: 0.002124  [  500/ 4500]
# Train loss: 0.001878  [ 1000/ 4500]
# Train loss: 0.002670  [ 1500/ 4500]
# Train loss: 0.002262  [ 2000/ 4500]
# Train loss: 0.002053  [ 2500/ 4500]
# Train loss: 0.001749  [ 3000/ 4500]
# Train loss: 0.002209  [ 3500/ 4500]
# Train loss: 0.001791  [ 4000/ 4500]
# Test Loss:  0.010618
#
# Epoch 163
# -------------------------------
# Train loss: 0.001702  [    0/ 4500]
# Train loss: 0.002097  [  500/ 4500]
# Train loss: 0.001859  [ 1000/ 4500]
# Train loss: 0.002647  [ 1500/ 4500]
# Train loss: 0.002240  [ 2000/ 4500]
# Train loss: 0.002036  [ 2500/ 4500]
# Train loss: 0.001734  [ 3000/ 4500]
# Train loss: 0.002190  [ 3500/ 4500]
# Train loss: 0.001772  [ 4000/ 4500]
# Test Loss:  0.010607
#
# Epoch 164
# -------------------------------
# Train loss: 0.001685  [    0/ 4500]
# Train loss: 0.002070  [  500/ 4500]
# Train loss: 0.001841  [ 1000/ 4500]
# Train loss: 0.002625  [ 1500/ 4500]
# Train loss: 0.002219  [ 2000/ 4500]
# Train loss: 0.002018  [ 2500/ 4500]
# Train loss: 0.001717  [ 3000/ 4500]
# Train loss: 0.002173  [ 3500/ 4500]
# Train loss: 0.001754  [ 4000/ 4500]
# Test Loss:  0.010597
#
# Epoch 165
# -------------------------------
# Train loss: 0.001668  [    0/ 4500]
# Train loss: 0.002046  [  500/ 4500]
# Train loss: 0.001824  [ 1000/ 4500]
# Train loss: 0.002601  [ 1500/ 4500]
# Train loss: 0.002196  [ 2000/ 4500]
# Train loss: 0.002000  [ 2500/ 4500]
# Train loss: 0.001701  [ 3000/ 4500]
# Train loss: 0.002153  [ 3500/ 4500]
# Train loss: 0.001737  [ 4000/ 4500]
# Test Loss:  0.010588
#
# Epoch 166
# -------------------------------
# Train loss: 0.001652  [    0/ 4500]
# Train loss: 0.002022  [  500/ 4500]
# Train loss: 0.001807  [ 1000/ 4500]
# Train loss: 0.002578  [ 1500/ 4500]
# Train loss: 0.002175  [ 2000/ 4500]
# Train loss: 0.001983  [ 2500/ 4500]
# Train loss: 0.001685  [ 3000/ 4500]
# Train loss: 0.002135  [ 3500/ 4500]
# Train loss: 0.001720  [ 4000/ 4500]
# Test Loss:  0.010579
#
# Epoch 167
# -------------------------------
# Train loss: 0.001636  [    0/ 4500]
# Train loss: 0.001998  [  500/ 4500]
# Train loss: 0.001790  [ 1000/ 4500]
# Train loss: 0.002553  [ 1500/ 4500]
# Train loss: 0.002153  [ 2000/ 4500]
# Train loss: 0.001966  [ 2500/ 4500]
# Train loss: 0.001669  [ 3000/ 4500]
# Train loss: 0.002116  [ 3500/ 4500]
# Train loss: 0.001703  [ 4000/ 4500]
# Test Loss:  0.010570
#
# Epoch 168
# -------------------------------
# Train loss: 0.001620  [    0/ 4500]
# Train loss: 0.001975  [  500/ 4500]
# Train loss: 0.001772  [ 1000/ 4500]
# Train loss: 0.002530  [ 1500/ 4500]
# Train loss: 0.002132  [ 2000/ 4500]
# Train loss: 0.001949  [ 2500/ 4500]
# Train loss: 0.001652  [ 3000/ 4500]
# Train loss: 0.002098  [ 3500/ 4500]
# Train loss: 0.001687  [ 4000/ 4500]
# Test Loss:  0.010562
#
# Epoch 169
# -------------------------------
# Train loss: 0.001605  [    0/ 4500]
# Train loss: 0.001951  [  500/ 4500]
# Train loss: 0.001754  [ 1000/ 4500]
# Train loss: 0.002508  [ 1500/ 4500]
# Train loss: 0.002111  [ 2000/ 4500]
# Train loss: 0.001932  [ 2500/ 4500]
# Train loss: 0.001636  [ 3000/ 4500]
# Train loss: 0.002080  [ 3500/ 4500]
# Train loss: 0.001670  [ 4000/ 4500]
# Test Loss:  0.010554
#
# Epoch 170
# -------------------------------
# Train loss: 0.001590  [    0/ 4500]
# Train loss: 0.001927  [  500/ 4500]
# Train loss: 0.001736  [ 1000/ 4500]
# Train loss: 0.002483  [ 1500/ 4500]
# Train loss: 0.002090  [ 2000/ 4500]
# Train loss: 0.001916  [ 2500/ 4500]
# Train loss: 0.001619  [ 3000/ 4500]
# Train loss: 0.002061  [ 3500/ 4500]
# Train loss: 0.001652  [ 4000/ 4500]
# Test Loss:  0.010548
#
# Epoch 171
# -------------------------------
# Train loss: 0.001576  [    0/ 4500]
# Train loss: 0.001903  [  500/ 4500]
# Train loss: 0.001719  [ 1000/ 4500]
# Train loss: 0.002460  [ 1500/ 4500]
# Train loss: 0.002070  [ 2000/ 4500]
# Train loss: 0.001900  [ 2500/ 4500]
# Train loss: 0.001604  [ 3000/ 4500]
# Train loss: 0.002042  [ 3500/ 4500]
# Train loss: 0.001635  [ 4000/ 4500]
# Test Loss:  0.010540
#
# Epoch 172
# -------------------------------
# Train loss: 0.001562  [    0/ 4500]
# Train loss: 0.001882  [  500/ 4500]
# Train loss: 0.001702  [ 1000/ 4500]
# Train loss: 0.002437  [ 1500/ 4500]
# Train loss: 0.002049  [ 2000/ 4500]
# Train loss: 0.001884  [ 2500/ 4500]
# Train loss: 0.001589  [ 3000/ 4500]
# Train loss: 0.002023  [ 3500/ 4500]
# Train loss: 0.001618  [ 4000/ 4500]
# Test Loss:  0.010532
#
# Epoch 173
# -------------------------------
# Train loss: 0.001547  [    0/ 4500]
# Train loss: 0.001859  [  500/ 4500]
# Train loss: 0.001685  [ 1000/ 4500]
# Train loss: 0.002414  [ 1500/ 4500]
# Train loss: 0.002028  [ 2000/ 4500]
# Train loss: 0.001868  [ 2500/ 4500]
# Train loss: 0.001574  [ 3000/ 4500]
# Train loss: 0.002004  [ 3500/ 4500]
# Train loss: 0.001602  [ 4000/ 4500]
# Test Loss:  0.010524
#
# Epoch 174
# -------------------------------
# Train loss: 0.001532  [    0/ 4500]
# Train loss: 0.001838  [  500/ 4500]
# Train loss: 0.001666  [ 1000/ 4500]
# Train loss: 0.002392  [ 1500/ 4500]
# Train loss: 0.002008  [ 2000/ 4500]
# Train loss: 0.001852  [ 2500/ 4500]
# Train loss: 0.001560  [ 3000/ 4500]
# Train loss: 0.001985  [ 3500/ 4500]
# Train loss: 0.001586  [ 4000/ 4500]
# Test Loss:  0.010515
#
# Epoch 175
# -------------------------------
# Train loss: 0.001516  [    0/ 4500]
# Train loss: 0.001818  [  500/ 4500]
# Train loss: 0.001648  [ 1000/ 4500]
# Train loss: 0.002370  [ 1500/ 4500]
# Train loss: 0.001989  [ 2000/ 4500]
# Train loss: 0.001836  [ 2500/ 4500]
# Train loss: 0.001545  [ 3000/ 4500]
# Train loss: 0.001966  [ 3500/ 4500]
# Train loss: 0.001571  [ 4000/ 4500]
# Test Loss:  0.010506
#
# Epoch 176
# -------------------------------
# Train loss: 0.001501  [    0/ 4500]
# Train loss: 0.001796  [  500/ 4500]
# Train loss: 0.001630  [ 1000/ 4500]
# Train loss: 0.002347  [ 1500/ 4500]
# Train loss: 0.001971  [ 2000/ 4500]
# Train loss: 0.001821  [ 2500/ 4500]
# Train loss: 0.001531  [ 3000/ 4500]
# Train loss: 0.001947  [ 3500/ 4500]
# Train loss: 0.001556  [ 4000/ 4500]
# Test Loss:  0.010499
#
# Epoch 177
# -------------------------------
# Train loss: 0.001486  [    0/ 4500]
# Train loss: 0.001775  [  500/ 4500]
# Train loss: 0.001613  [ 1000/ 4500]
# Train loss: 0.002326  [ 1500/ 4500]
# Train loss: 0.001952  [ 2000/ 4500]
# Train loss: 0.001806  [ 2500/ 4500]
# Train loss: 0.001517  [ 3000/ 4500]
# Train loss: 0.001929  [ 3500/ 4500]
# Train loss: 0.001541  [ 4000/ 4500]
# Test Loss:  0.010490
#
# Epoch 178
# -------------------------------
# Train loss: 0.001471  [    0/ 4500]
# Train loss: 0.001754  [  500/ 4500]
# Train loss: 0.001598  [ 1000/ 4500]
# Train loss: 0.002306  [ 1500/ 4500]
# Train loss: 0.001932  [ 2000/ 4500]
# Train loss: 0.001789  [ 2500/ 4500]
# Train loss: 0.001502  [ 3000/ 4500]
# Train loss: 0.001910  [ 3500/ 4500]
# Train loss: 0.001527  [ 4000/ 4500]
# Test Loss:  0.010482
#
# Epoch 179
# -------------------------------
# Train loss: 0.001457  [    0/ 4500]
# Train loss: 0.001732  [  500/ 4500]
# Train loss: 0.001584  [ 1000/ 4500]
# Train loss: 0.002285  [ 1500/ 4500]
# Train loss: 0.001912  [ 2000/ 4500]
# Train loss: 0.001774  [ 2500/ 4500]
# Train loss: 0.001486  [ 3000/ 4500]
# Train loss: 0.001893  [ 3500/ 4500]
# Train loss: 0.001510  [ 4000/ 4500]
# Test Loss:  0.010475
#
# Epoch 180
# -------------------------------
# Train loss: 0.001444  [    0/ 4500]
# Train loss: 0.001712  [  500/ 4500]
# Train loss: 0.001569  [ 1000/ 4500]
# Train loss: 0.002261  [ 1500/ 4500]
# Train loss: 0.001894  [ 2000/ 4500]
# Train loss: 0.001757  [ 2500/ 4500]
# Train loss: 0.001470  [ 3000/ 4500]
# Train loss: 0.001875  [ 3500/ 4500]
# Train loss: 0.001494  [ 4000/ 4500]
# Test Loss:  0.010467
#
# Epoch 181
# -------------------------------
# Train loss: 0.001430  [    0/ 4500]
# Train loss: 0.001693  [  500/ 4500]
# Train loss: 0.001551  [ 1000/ 4500]
# Train loss: 0.002241  [ 1500/ 4500]
# Train loss: 0.001875  [ 2000/ 4500]
# Train loss: 0.001742  [ 2500/ 4500]
# Train loss: 0.001457  [ 3000/ 4500]
# Train loss: 0.001857  [ 3500/ 4500]
# Train loss: 0.001479  [ 4000/ 4500]
# Test Loss:  0.010458
#
# Epoch 182
# -------------------------------
# Train loss: 0.001415  [    0/ 4500]
# Train loss: 0.001672  [  500/ 4500]
# Train loss: 0.001536  [ 1000/ 4500]
# Train loss: 0.002223  [ 1500/ 4500]
# Train loss: 0.001858  [ 2000/ 4500]
# Train loss: 0.001728  [ 2500/ 4500]
# Train loss: 0.001444  [ 3000/ 4500]
# Train loss: 0.001838  [ 3500/ 4500]
# Train loss: 0.001463  [ 4000/ 4500]
# Test Loss:  0.010450
#
# Epoch 183
# -------------------------------
# Train loss: 0.001401  [    0/ 4500]
# Train loss: 0.001652  [  500/ 4500]
# Train loss: 0.001519  [ 1000/ 4500]
# Train loss: 0.002202  [ 1500/ 4500]
# Train loss: 0.001840  [ 2000/ 4500]
# Train loss: 0.001711  [ 2500/ 4500]
# Train loss: 0.001429  [ 3000/ 4500]
# Train loss: 0.001819  [ 3500/ 4500]
# Train loss: 0.001449  [ 4000/ 4500]
# Test Loss:  0.010444
#
# Epoch 184
# -------------------------------
# Train loss: 0.001389  [    0/ 4500]
# Train loss: 0.001632  [  500/ 4500]
# Train loss: 0.001504  [ 1000/ 4500]
# Train loss: 0.002181  [ 1500/ 4500]
# Train loss: 0.001822  [ 2000/ 4500]
# Train loss: 0.001697  [ 2500/ 4500]
# Train loss: 0.001413  [ 3000/ 4500]
# Train loss: 0.001799  [ 3500/ 4500]
# Train loss: 0.001436  [ 4000/ 4500]
# Test Loss:  0.010437
#
# Epoch 185
# -------------------------------
# Train loss: 0.001375  [    0/ 4500]
# Train loss: 0.001614  [  500/ 4500]
# Train loss: 0.001490  [ 1000/ 4500]
# Train loss: 0.002159  [ 1500/ 4500]
# Train loss: 0.001804  [ 2000/ 4500]
# Train loss: 0.001683  [ 2500/ 4500]
# Train loss: 0.001400  [ 3000/ 4500]
# Train loss: 0.001780  [ 3500/ 4500]
# Train loss: 0.001422  [ 4000/ 4500]
# Test Loss:  0.010432
#
# Epoch 186
# -------------------------------
# Train loss: 0.001363  [    0/ 4500]
# Train loss: 0.001593  [  500/ 4500]
# Train loss: 0.001475  [ 1000/ 4500]
# Train loss: 0.002138  [ 1500/ 4500]
# Train loss: 0.001786  [ 2000/ 4500]
# Train loss: 0.001671  [ 2500/ 4500]
# Train loss: 0.001387  [ 3000/ 4500]
# Train loss: 0.001763  [ 3500/ 4500]
# Train loss: 0.001408  [ 4000/ 4500]
# Test Loss:  0.010426
#
# Epoch 187
# -------------------------------
# Train loss: 0.001351  [    0/ 4500]
# Train loss: 0.001574  [  500/ 4500]
# Train loss: 0.001459  [ 1000/ 4500]
# Train loss: 0.002117  [ 1500/ 4500]
# Train loss: 0.001771  [ 2000/ 4500]
# Train loss: 0.001659  [ 2500/ 4500]
# Train loss: 0.001376  [ 3000/ 4500]
# Train loss: 0.001747  [ 3500/ 4500]
# Train loss: 0.001395  [ 4000/ 4500]
# Test Loss:  0.010418
#
# Epoch 188
# -------------------------------
# Train loss: 0.001336  [    0/ 4500]
# Train loss: 0.001554  [  500/ 4500]
# Train loss: 0.001445  [ 1000/ 4500]
# Train loss: 0.002096  [ 1500/ 4500]
# Train loss: 0.001755  [ 2000/ 4500]
# Train loss: 0.001644  [ 2500/ 4500]
# Train loss: 0.001363  [ 3000/ 4500]
# Train loss: 0.001729  [ 3500/ 4500]
# Train loss: 0.001382  [ 4000/ 4500]
# Test Loss:  0.010412
#
# Epoch 189
# -------------------------------
# Train loss: 0.001324  [    0/ 4500]
# Train loss: 0.001535  [  500/ 4500]
# Train loss: 0.001432  [ 1000/ 4500]
# Train loss: 0.002075  [ 1500/ 4500]
# Train loss: 0.001739  [ 2000/ 4500]
# Train loss: 0.001634  [ 2500/ 4500]
# Train loss: 0.001352  [ 3000/ 4500]
# Train loss: 0.001709  [ 3500/ 4500]
# Train loss: 0.001371  [ 4000/ 4500]
# Test Loss:  0.010406
#
# Epoch 190
# -------------------------------
# Train loss: 0.001312  [    0/ 4500]
# Train loss: 0.001517  [  500/ 4500]
# Train loss: 0.001419  [ 1000/ 4500]
# Train loss: 0.002056  [ 1500/ 4500]
# Train loss: 0.001722  [ 2000/ 4500]
# Train loss: 0.001620  [ 2500/ 4500]
# Train loss: 0.001341  [ 3000/ 4500]
# Train loss: 0.001694  [ 3500/ 4500]
# Train loss: 0.001358  [ 4000/ 4500]
# Test Loss:  0.010404
#
# Epoch 191
# -------------------------------
# Train loss: 0.001303  [    0/ 4500]
# Train loss: 0.001501  [  500/ 4500]
# Train loss: 0.001404  [ 1000/ 4500]
# Train loss: 0.002039  [ 1500/ 4500]
# Train loss: 0.001706  [ 2000/ 4500]
# Train loss: 0.001607  [ 2500/ 4500]
# Train loss: 0.001327  [ 3000/ 4500]
# Train loss: 0.001677  [ 3500/ 4500]
# Train loss: 0.001345  [ 4000/ 4500]
# Test Loss:  0.010401
#
# Epoch 192
# -------------------------------
# Train loss: 0.001293  [    0/ 4500]
# Train loss: 0.001485  [  500/ 4500]
# Train loss: 0.001386  [ 1000/ 4500]
# Train loss: 0.002019  [ 1500/ 4500]
# Train loss: 0.001692  [ 2000/ 4500]
# Train loss: 0.001595  [ 2500/ 4500]
# Train loss: 0.001314  [ 3000/ 4500]
# Train loss: 0.001661  [ 3500/ 4500]
# Train loss: 0.001336  [ 4000/ 4500]
# Test Loss:  0.010390
#
# Epoch 193
# -------------------------------
# Train loss: 0.001277  [    0/ 4500]
# Train loss: 0.001466  [  500/ 4500]
# Train loss: 0.001368  [ 1000/ 4500]
# Train loss: 0.001999  [ 1500/ 4500]
# Train loss: 0.001679  [ 2000/ 4500]
# Train loss: 0.001582  [ 2500/ 4500]
# Train loss: 0.001303  [ 3000/ 4500]
# Train loss: 0.001642  [ 3500/ 4500]
# Train loss: 0.001325  [ 4000/ 4500]
# Test Loss:  0.010385
#
# Epoch 194
# -------------------------------
# Train loss: 0.001265  [    0/ 4500]
# Train loss: 0.001449  [  500/ 4500]
# Train loss: 0.001355  [ 1000/ 4500]
# Train loss: 0.001984  [ 1500/ 4500]
# Train loss: 0.001665  [ 2000/ 4500]
# Train loss: 0.001570  [ 2500/ 4500]
# Train loss: 0.001293  [ 3000/ 4500]
# Train loss: 0.001627  [ 3500/ 4500]
# Train loss: 0.001313  [ 4000/ 4500]
# Test Loss:  0.010382
#
# Epoch 195
# -------------------------------
# Train loss: 0.001256  [    0/ 4500]
# Train loss: 0.001438  [  500/ 4500]
# Train loss: 0.001342  [ 1000/ 4500]
# Train loss: 0.001962  [ 1500/ 4500]
# Train loss: 0.001650  [ 2000/ 4500]
# Train loss: 0.001555  [ 2500/ 4500]
# Train loss: 0.001280  [ 3000/ 4500]
# Train loss: 0.001612  [ 3500/ 4500]
# Train loss: 0.001302  [ 4000/ 4500]
# Test Loss:  0.010378
#
# Epoch 196
# -------------------------------
# Train loss: 0.001247  [    0/ 4500]
# Train loss: 0.001422  [  500/ 4500]
# Train loss: 0.001326  [ 1000/ 4500]
# Train loss: 0.001945  [ 1500/ 4500]
# Train loss: 0.001634  [ 2000/ 4500]
# Train loss: 0.001540  [ 2500/ 4500]
# Train loss: 0.001269  [ 3000/ 4500]
# Train loss: 0.001594  [ 3500/ 4500]
# Train loss: 0.001291  [ 4000/ 4500]
# Test Loss:  0.010369
#
# Epoch 197
# -------------------------------
# Train loss: 0.001232  [    0/ 4500]
# Train loss: 0.001402  [  500/ 4500]
# Train loss: 0.001312  [ 1000/ 4500]
# Train loss: 0.001928  [ 1500/ 4500]
# Train loss: 0.001617  [ 2000/ 4500]
# Train loss: 0.001523  [ 2500/ 4500]
# Train loss: 0.001257  [ 3000/ 4500]
# Train loss: 0.001580  [ 3500/ 4500]
# Train loss: 0.001278  [ 4000/ 4500]
# Test Loss:  0.010364
#
# Epoch 198
# -------------------------------
# Train loss: 0.001220  [    0/ 4500]
# Train loss: 0.001385  [  500/ 4500]
# Train loss: 0.001299  [ 1000/ 4500]
# Train loss: 0.001910  [ 1500/ 4500]
# Train loss: 0.001602  [ 2000/ 4500]
# Train loss: 0.001509  [ 2500/ 4500]
# Train loss: 0.001246  [ 3000/ 4500]
# Train loss: 0.001562  [ 3500/ 4500]
# Train loss: 0.001265  [ 4000/ 4500]
# Test Loss:  0.010366
#
# Epoch 199
# -------------------------------
# Train loss: 0.001215  [    0/ 4500]
# Train loss: 0.001373  [  500/ 4500]
# Train loss: 0.001295  [ 1000/ 4500]
# Train loss: 0.001894  [ 1500/ 4500]
# Train loss: 0.001586  [ 2000/ 4500]
# Train loss: 0.001496  [ 2500/ 4500]
# Train loss: 0.001234  [ 3000/ 4500]
# Train loss: 0.001547  [ 3500/ 4500]
# Train loss: 0.001254  [ 4000/ 4500]
# Test Loss:  0.010359
#
# Epoch 200
# -------------------------------
# Train loss: 0.001201  [    0/ 4500]
# Train loss: 0.001360  [  500/ 4500]
# Train loss: 0.001286  [ 1000/ 4500]
# Train loss: 0.001873  [ 1500/ 4500]
# Train loss: 0.001571  [ 2000/ 4500]
# Train loss: 0.001485  [ 2500/ 4500]
# Train loss: 0.001224  [ 3000/ 4500]
# Train loss: 0.001530  [ 3500/ 4500]
# Train loss: 0.001244  [ 4000/ 4500]
# Test Loss:  0.010354
#
# Done!

# %%
# %%
plt.figure(figsize = (8,6))
plt.title("MSE Loss vs Epochs")
plt.plot(steps, torch.FloatTensor(Loss_train).cpu(), label = 'train')
plt.plot(steps, Loss_test, label = 'test')
plt.xlabel("Epochs")
plt.ylabel("MSE Loss")
plt.legend()
plt.show()
        
#%%
torch.cuda.empty_cache()
#%%


#%%
# figure configuration
font = {'family' : 'Arial',
        'weight' : 'bold',
        'size'   : 22}

plt.rc('font', **font)

# %%
torch.save(model.state_dict(), 'model/exp_mlmodel6.dat')

#%%  test model

test_model = NeuralNetwork().to('cpu')
# test_model =UNet().to('cpu')

test_model.load_state_dict(torch.load('model/exp_mlmodel6.dat'))
# Out:
# <All keys matched successfully>

# %%
md = test_model.state_dict()
Ts = md['my1.weights1']
# plt.figure(figsize = (10,10))
# plt.imshow(Ts[:,1784:2784],cmap = 'rainbow')
# plt.colorbar()
# plt.show()

# %%
import pickle

with open("matrix/natural_matrix/large_T75M016_matrix.dat", 'wb') as f:
    pickle.dump(Ts, f)

# %%
# tt = np.mean(np.array(Ts), axis = 0)

# plt.figure()
# plt.imshow(tt.reshape(112,112), cmap = 'rainbow')
# # plt.clim(-0.1,0.1)
# plt.colorbar()
# plt.show()

# %%
# u, s, vh = np.linalg.svd(Ts, full_matrices = False)

# %%
# plt.figure()
# plt.imshow(s)
# plt.show()

# %%
test_number = np.random.randint(0,50)

with torch.no_grad():
    test_model.eval()
    X= x_test[test_number].reshape(-1,1,*input_dim)
    pred = test_model(X)
plt.figure(figsize = (10,8)) 
plt.subplot(121)
plt.imshow(y_test[test_number].reshape(output_dim), cmap = 'gray')  
plt.axis('off')
plt.subplot(122)
plt.imshow(pred[0].reshape(output_dim), cmap = 'gray')
plt.axis('off')
# plt.imshow(pred[0].reshape(64,64))
plt.show()

# %% [markdown]
# ## Test use different temperature

# %%
# with open("data/Natural_temp_cifar/Speckle_20x_400um_Round_Scale-2x_Natural_M_012_T55_112x112_5000.dat", 'rb') as f:
#     i_list = pickle.load(f)

# # with open("data/Temperature/Digits_5000.dat", 'rb') as f:
# #     output_list =pickle.load(f)
    
# test_i = rn[17]

# sample = torch.FloatTensor(i_list[test_i]/255.0)
# sample_ground = torch.FloatTensor(output_list[test_i]/255.0)
    
# with torch.no_grad():
#     test_model.eval()
#     X= sample.reshape(-1,1,*input_dim)
#     pred = test_model(X)
# plt.figure(figsize = (10,8)) 
# plt.subplot(121)
# plt.imshow(sample_ground.reshape(output_dim), cmap = 'gray')  
# plt.axis('off')
# plt.subplot(122)
# plt.imshow(pred[0].reshape(output_dim), cmap = 'gray')
# # plt.imshow(pred[0].reshape(64,64))
# plt.axis('off')
# plt.show()

# %%
#%%
test_number = np.random.randint(0,90)

with torch.no_grad():
    test_model.eval()
    X= x_train[test_number].reshape(-1,1,*input_dim)
    pred = test_model(X)
plt.figure(figsize = (10,8)) 
plt.subplot(121)
plt.imshow(y_train[test_number].reshape(output_dim), cmap = 'gray')  
plt.axis('off')
plt.subplot(122)
plt.imshow(pred[0].reshape(output_dim), cmap = 'gray')
plt.axis('off')
plt.show()

#%%
# test_number = np.random.randint(0,500)

# with torch.no_grad():
#     test_model.eval()
#     X = x_train[test_number].reshape(-1,1, *input_dim)

#     pred = test_model(X)
  
# plt.figure() 

# plt.subplot(121)
# plt.imshow(y_train[test_number].reshape(64,64), cmap = 'gray')  
# plt.subplot(122)
# plt.imshow(pred[0].reshape(64,64), cmap = 'gray')
# plt.show()
