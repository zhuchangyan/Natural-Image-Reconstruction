# %%
# -*- coding: utf-8 -*-
"""
Created on Fri May  6 15:14:16 2022

@author: zhuch
"""

# -*- coding: utf-8 -*-
"""
Created on Thu May  5 17:30:53 2022

@author: zhuch
"""

import pickle

import numpy as np
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda, Compose
import matplotlib.pyplot as plt
import torch.nn.functional as F
import h5py
#%%

# with open("speckle.dat", 'rb') as f:
#     input_list = pickle.load(f)

# with open("SLM.dat", 'rb') as f:
#     output_list =pickle.load(f)
    
#%%

# with open("data/experiment results/Speckle_20x_200um_Round_Scale-2.5x_Natural_M_2_10238_112x112.dat", 'rb') as f:
#     input_list = pickle.load(f)

# with open("data/experiment results/Natural_10238.dat", 'rb') as f:
#     output_list =pickle.load(f)
    
#%%

with open("data/Temperature/Speckle_400um_Digits_M6_T75_112x112_5000.dat", 'rb') as f:
    input_list = pickle.load(f)

with open("data/Temperature/Digits_5000.dat", 'rb') as f:
    output_list =pickle.load(f)


#%%
# pathname = "data/natcom/Data_1m.h5"
    

# hf = h5py.File(pathname, 'r')
# name1 = 'Training/Original_images/ImageNet'
# name2 = 'Training/Speckle_images/ImageNet'

# output_list = hf[name1]
# input_list = hf[name2]

# %%
#%%
import matplotlib.pyplot as plt

idx = np.random.randint(0,5000)
# idx = 2600

plt.figure()
plt.subplot(121)
plt.imshow(output_list[idx], cmap = 'gray')
plt.subplot(122)
plt.imshow(input_list[idx].reshape(112,112), cmap = 'gray')
plt.show()

# %%
np.shape(input_list)
# Out:
# (5000, 112, 112, 1)

# %%
#%%
# s = input_list[5]
# x = np.arange(0,112,1)
# y = np.arange(0,112,1)
# X,Y = np.meshgrid(x,y)
# plt.figure()
# ax = plt.axes(projection='3d')
# ax.scatter(X,Y,s.reshape(112,112), cmap='viridis')
# # plt.colorbar()
# plt.show()

#%%
N_sample = 5000
start_id = 0
train_rate = 0.9
train_set_number = int(train_rate*N_sample)

output_dim = (112,112)
input_dim = (28,28)

input_H = np.array(output_list).reshape(-1,1, *input_dim)
label = np.array(input_list).reshape(-1,1, *output_dim)

train_number = np.arange(start_id,start_id + N_sample, dtype ='int')
np.random.shuffle(train_number)
#
x_train = input_H[train_number[0:train_set_number]]
x_test = input_H[train_number[train_set_number:N_sample]]

y_train =label[train_number[0:train_set_number]]
y_test = label[train_number[train_set_number:N_sample]]

x_train = torch.FloatTensor(x_train/255.0)
x_test = torch.FloatTensor(x_test/255.0)

# x_train = torch.sqrt(x_train)
# x_test = torch.sqrt(x_test)

y_train = torch.FloatTensor(y_train/255.0)
y_test = torch.FloatTensor(y_test/255.0)
    
    

#%%
# del input_list
# del output_list
# del input_H
# del label
#%%
torch.cuda.empty_cache()

# %%
batch_size = 100

# create data loaders
train_dataloader = DataLoader(list(zip(x_train, y_train)), batch_size = batch_size )
test_dataloader = DataLoader(list(zip(x_test,y_test)),  batch_size = batch_size )

# %%
import math

class complexLayer(nn.Module):
    """ Custom Linear layer but mimics a standard linear layer """
    def __init__(self, size_in, size_out):
        super().__init__()
        self.size_in, self.size_out = size_in, size_out
        weights1 = torch.Tensor(size_out, size_in)
        self.weights1 = nn.Parameter(weights1)  # nn.Parameter is a Tensor that's a module parameter.
#         weights2 = torch.Tensor(size_out, size_in)
#         self.weights2 = nn.Parameter(weights2)

        # initialize weights and biases
        nn.init.kaiming_uniform_(self.weights1, a=math.sqrt(5)) # weight init
#         nn.init.kaiming_uniform_(self.weights2, a=math.sqrt(5)) # weight init


    def forward(self, x):
        x1 = torch.mm(x,self.weights1.t())
#         x1 = torch.square(torch.mm(torch.cos(x),self.weights1.t()))
#         x2 = torch.square(torch.mm(torch.sin(x),self.weights2.t()))
#         x =  torch.add(x1,x2)
        return x1

#%%

device = "cuda"
import torch.nn.functional as F

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.my1 = complexLayer(784, 112*112)
        self.flatten = nn.Flatten()

    def forward(self, x):
        x = self.flatten(x)
        x = self.my1(x)
        x = x.view(-1, 1, 112, 112)
        return x

model = NeuralNetwork().to(device)

# %% [markdown]
# I = np.square(abs( T* Input_image))
#
# I = T' * Input_image
#
# Input_image: 64x64
# I: 112x112
# T: 4096x (112x112)

# %%
# ######## Define model
# device = 'cuda'
# class NeuralNetwork(nn.Module):
#     def __init__(self):
#         super(NeuralNetwork, self).__init__()
#         self.fc1 = nn.Linear(112*112, 28*28)
#         self.flatten = nn.Flatten()
        
#     def forward(self, x):
#         x3 = self.flatten(x)
#         x4 = self.fc1(x3)
#         x5 = x4.view(-1,1,28,28)
#         return x5

# model = NeuralNetwork().to(device)
# from torchsummary import summary
# summary(model, (1, 112, 112))

# %%
# device = 'cuda'
# Nnodes = 4096

# class NeuralNetwork(nn.Module):
#     def __init__(self):
#         super(NeuralNetwork, self).__init__()
#         self.fc1 = nn.Linear(112*112, Nnodes)
#         self.fc2 = nn.Linear(Nnodes, 28*28)
#         self.dp = nn.Dropout(0.3)
#         self.BN = nn.BatchNorm1d(Nnodes)
#         self.BN2 = nn.BatchNorm1d(28*28)  
#         self.flatten = nn.Flatten()
        
#     def forward(self, x):
#         x = self.flatten(x)
#         x = self.BN(self.dp(F.relu(self.fc1(x))))
#         x = self.BN2(self.dp(F.sigmoid(self.fc2(x))))
#         # x = self.dp(F.relu(self.fc2(x)))
#         x = x.view(-1,1,28,28)
#         return x

# model = NeuralNetwork().to(device)
# from torchsummary import summary
# summary(model, (1, 112, 112))

# %%
# !pip install torchsummary

# %%
#%%
import ssim
from torch.optim.lr_scheduler import ReduceLROnPlateau

# loss_fn = ssim.SSIM()
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=2e-2)
# optimizer = Nadam(model.parameters(), lr=1e-3)
scheduler = ReduceLROnPlateau(optimizer)


def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        
        optimizer.step()

        if batch % 10 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"Train loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    return loss
#     return loss.cpu().detach().numpy()       
            
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
    test_loss /= num_batches
    print(f"Test Loss:  {test_loss:>8f} \n")
    return test_loss

# %%
#%%  Neural network training


epochs = 200

Loss_train = []
Loss_test = []
steps = []


best_loss = 1.0


for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loss = train(train_dataloader, model, loss_fn, optimizer)
    test_loss = test(test_dataloader, model, loss_fn)
    Loss_train.append(train_loss)
    Loss_test.append(test_loss)
    if test_loss<best_loss:
        best_loss = test_loss
    steps.append(t)
    scheduler.step(test_loss)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Train loss: 0.105359  [    0/ 4500]
# Train loss: 0.667134  [ 1000/ 4500]
# Train loss: 0.323825  [ 2000/ 4500]
# Train loss: 0.124119  [ 3000/ 4500]
# Train loss: 0.047117  [ 4000/ 4500]
# Test Loss:  0.028280
#
# Epoch 2
# -------------------------------
# Train loss: 0.024468  [    0/ 4500]
# Train loss: 0.016175  [ 1000/ 4500]
# Train loss: 0.012547  [ 2000/ 4500]
# Train loss: 0.008758  [ 3000/ 4500]
# Train loss: 0.007831  [ 4000/ 4500]
# Test Loss:  0.006998
#
# Epoch 3
# -------------------------------
# Train loss: 0.006496  [    0/ 4500]
# Train loss: 0.008065  [ 1000/ 4500]
# Train loss: 0.006190  [ 2000/ 4500]
# Train loss: 0.005661  [ 3000/ 4500]
# Train loss: 0.005917  [ 4000/ 4500]
# Test Loss:  0.005967
#
# Epoch 4
# -------------------------------
# Train loss: 0.005549  [    0/ 4500]
# Train loss: 0.006448  [ 1000/ 4500]
# Train loss: 0.005342  [ 2000/ 4500]
# Train loss: 0.004971  [ 3000/ 4500]
# Train loss: 0.005411  [ 4000/ 4500]
# Test Loss:  0.005596
#
# Epoch 5
# -------------------------------
# Train loss: 0.005102  [    0/ 4500]
# Train loss: 0.005554  [ 1000/ 4500]
# Train loss: 0.004878  [ 2000/ 4500]
# Train loss: 0.004754  [ 3000/ 4500]
# Train loss: 0.005182  [ 4000/ 4500]
# Test Loss:  0.005461
#
# Epoch 6
# -------------------------------
# Train loss: 0.004945  [    0/ 4500]
# Train loss: 0.005252  [ 1000/ 4500]
# Train loss: 0.004676  [ 2000/ 4500]
# Train loss: 0.004660  [ 3000/ 4500]
# Train loss: 0.005031  [ 4000/ 4500]
# Test Loss:  0.005401
#
# Epoch 7
# -------------------------------
# Train loss: 0.004835  [    0/ 4500]
# Train loss: 0.004967  [ 1000/ 4500]
# Train loss: 0.004629  [ 2000/ 4500]
# Train loss: 0.004643  [ 3000/ 4500]
# Train loss: 0.004978  [ 4000/ 4500]
# Test Loss:  0.005419
#
# Epoch 8
# -------------------------------
# Train loss: 0.004779  [    0/ 4500]
# Train loss: 0.004826  [ 1000/ 4500]
# Train loss: 0.004776  [ 2000/ 4500]
# Train loss: 0.004680  [ 3000/ 4500]
# Train loss: 0.004983  [ 4000/ 4500]
# Test Loss:  0.005468
#
# Epoch 9
# -------------------------------
# Train loss: 0.004779  [    0/ 4500]
# Train loss: 0.004783  [ 1000/ 4500]
# Train loss: 0.005063  [ 2000/ 4500]
# Train loss: 0.004787  [ 3000/ 4500]
# Train loss: 0.005032  [ 4000/ 4500]
# Test Loss:  0.005541
#
# Epoch 10
# -------------------------------
# Train loss: 0.004840  [    0/ 4500]
# Train loss: 0.004806  [ 1000/ 4500]
# Train loss: 0.005418  [ 2000/ 4500]
# Train loss: 0.004960  [ 3000/ 4500]
# Train loss: 0.005123  [ 4000/ 4500]
# Test Loss:  0.005635
#
# Epoch 11
# -------------------------------
# Train loss: 0.004924  [    0/ 4500]
# Train loss: 0.004851  [ 1000/ 4500]
# Train loss: 0.005767  [ 2000/ 4500]
# Train loss: 0.005122  [ 3000/ 4500]
# Train loss: 0.005233  [ 4000/ 4500]
# Test Loss:  0.005735
#
# Epoch 12
# -------------------------------
# Train loss: 0.004988  [    0/ 4500]
# Train loss: 0.004891  [ 1000/ 4500]
# Train loss: 0.006078  [ 2000/ 4500]
# Train loss: 0.005192  [ 3000/ 4500]
# Train loss: 0.005379  [ 4000/ 4500]
# Test Loss:  0.005862
#
# Epoch 13
# -------------------------------
# Train loss: 0.005072  [    0/ 4500]
# Train loss: 0.004958  [ 1000/ 4500]
# Train loss: 0.006486  [ 2000/ 4500]
# Train loss: 0.005205  [ 3000/ 4500]
# Train loss: 0.005574  [ 4000/ 4500]
# Test Loss:  0.006068
#
# Epoch 14
# -------------------------------
# Train loss: 0.005234  [    0/ 4500]
# Train loss: 0.005074  [ 1000/ 4500]
# Train loss: 0.007029  [ 2000/ 4500]
# Train loss: 0.005323  [ 3000/ 4500]
# Train loss: 0.005786  [ 4000/ 4500]
# Test Loss:  0.006321
#
# Epoch 15
# -------------------------------
# Train loss: 0.005451  [    0/ 4500]
# Train loss: 0.005226  [ 1000/ 4500]
# Train loss: 0.007637  [ 2000/ 4500]
# Train loss: 0.005498  [ 3000/ 4500]
# Train loss: 0.006054  [ 4000/ 4500]
# Test Loss:  0.006605
#
# Epoch 16
# -------------------------------
# Train loss: 0.005704  [    0/ 4500]
# Train loss: 0.005436  [ 1000/ 4500]
# Train loss: 0.008231  [ 2000/ 4500]
# Train loss: 0.005876  [ 3000/ 4500]
# Train loss: 0.006402  [ 4000/ 4500]
# Test Loss:  0.006926
#
# Epoch 17
# -------------------------------
# Train loss: 0.005988  [    0/ 4500]
# Train loss: 0.005726  [ 1000/ 4500]
# Train loss: 0.008735  [ 2000/ 4500]
# Train loss: 0.006314  [ 3000/ 4500]
# Train loss: 0.006762  [ 4000/ 4500]
# Test Loss:  0.007335
#
# Epoch 18
# -------------------------------
# Train loss: 0.006337  [    0/ 4500]
# Train loss: 0.004981  [ 1000/ 4500]
# Train loss: 0.004634  [ 2000/ 4500]
# Train loss: 0.003742  [ 3000/ 4500]
# Train loss: 0.004039  [ 4000/ 4500]
# Test Loss:  0.004894
#
# Epoch 19
# -------------------------------
# Train loss: 0.004189  [    0/ 4500]
# Train loss: 0.004132  [ 1000/ 4500]
# Train loss: 0.003853  [ 2000/ 4500]
# Train loss: 0.003605  [ 3000/ 4500]
# Train loss: 0.003976  [ 4000/ 4500]
# Test Loss:  0.004802
#
# Epoch 20
# -------------------------------
# Train loss: 0.004120  [    0/ 4500]
# Train loss: 0.003995  [ 1000/ 4500]
# Train loss: 0.003741  [ 2000/ 4500]
# Train loss: 0.003597  [ 3000/ 4500]
# Train loss: 0.003947  [ 4000/ 4500]
# Test Loss:  0.004777
#
# Epoch 21
# -------------------------------
# Train loss: 0.004091  [    0/ 4500]
# Train loss: 0.003944  [ 1000/ 4500]
# Train loss: 0.003697  [ 2000/ 4500]
# Train loss: 0.003589  [ 3000/ 4500]
# Train loss: 0.003927  [ 4000/ 4500]
# Test Loss:  0.004762
#
# Epoch 22
# -------------------------------
# Train loss: 0.004068  [    0/ 4500]
# Train loss: 0.003917  [ 1000/ 4500]
# Train loss: 0.003671  [ 2000/ 4500]
# Train loss: 0.003582  [ 3000/ 4500]
# Train loss: 0.003913  [ 4000/ 4500]
# Test Loss:  0.004752
#
# Epoch 23
# -------------------------------
# Train loss: 0.004050  [    0/ 4500]
# Train loss: 0.003901  [ 1000/ 4500]
# Train loss: 0.003653  [ 2000/ 4500]
# Train loss: 0.003577  [ 3000/ 4500]
# Train loss: 0.003904  [ 4000/ 4500]
# Test Loss:  0.004744
#
# Epoch 24
# -------------------------------
# Train loss: 0.004034  [    0/ 4500]
# Train loss: 0.003891  [ 1000/ 4500]
# Train loss: 0.003641  [ 2000/ 4500]
# Train loss: 0.003573  [ 3000/ 4500]
# Train loss: 0.003897  [ 4000/ 4500]
# Test Loss:  0.004737
#
# Epoch 25
# -------------------------------
# Train loss: 0.004020  [    0/ 4500]
# Train loss: 0.003884  [ 1000/ 4500]
# Train loss: 0.003633  [ 2000/ 4500]
# Train loss: 0.003572  [ 3000/ 4500]
# Train loss: 0.003892  [ 4000/ 4500]
# Test Loss:  0.004730
#
# Epoch 26
# -------------------------------
# Train loss: 0.004007  [    0/ 4500]
# Train loss: 0.003879  [ 1000/ 4500]
# Train loss: 0.003629  [ 2000/ 4500]
# Train loss: 0.003571  [ 3000/ 4500]
# Train loss: 0.003888  [ 4000/ 4500]
# Test Loss:  0.004725
#
# Epoch 27
# -------------------------------
# Train loss: 0.003993  [    0/ 4500]
# Train loss: 0.003875  [ 1000/ 4500]
# Train loss: 0.003627  [ 2000/ 4500]
# Train loss: 0.003572  [ 3000/ 4500]
# Train loss: 0.003885  [ 4000/ 4500]
# Test Loss:  0.004719
#
# Epoch 28
# -------------------------------
# Train loss: 0.003979  [    0/ 4500]
# Train loss: 0.003871  [ 1000/ 4500]
# Train loss: 0.003626  [ 2000/ 4500]
# Train loss: 0.003574  [ 3000/ 4500]
# Train loss: 0.003883  [ 4000/ 4500]
# Test Loss:  0.004715
#
# Epoch 29
# -------------------------------
# Train loss: 0.003964  [    0/ 4500]
# Train loss: 0.003866  [ 1000/ 4500]
# Train loss: 0.003625  [ 2000/ 4500]
# Train loss: 0.003575  [ 3000/ 4500]
# Train loss: 0.003883  [ 4000/ 4500]
# Test Loss:  0.004711
#
# Epoch 30
# -------------------------------
# Train loss: 0.003948  [    0/ 4500]
# Train loss: 0.003861  [ 1000/ 4500]
# Train loss: 0.003623  [ 2000/ 4500]
# Train loss: 0.003575  [ 3000/ 4500]
# Train loss: 0.003884  [ 4000/ 4500]
# Test Loss:  0.004708
#
# Epoch 31
# -------------------------------
# Train loss: 0.003933  [    0/ 4500]
# Train loss: 0.003855  [ 1000/ 4500]
# Train loss: 0.003619  [ 2000/ 4500]
# Train loss: 0.003573  [ 3000/ 4500]
# Train loss: 0.003886  [ 4000/ 4500]
# Test Loss:  0.004706
#
# Epoch 32
# -------------------------------
# Train loss: 0.003919  [    0/ 4500]
# Train loss: 0.003850  [ 1000/ 4500]
# Train loss: 0.003613  [ 2000/ 4500]
# Train loss: 0.003570  [ 3000/ 4500]
# Train loss: 0.003889  [ 4000/ 4500]
# Test Loss:  0.004706
#
# Epoch 33
# -------------------------------
# Train loss: 0.003908  [    0/ 4500]
# Train loss: 0.003847  [ 1000/ 4500]
# Train loss: 0.003606  [ 2000/ 4500]
# Train loss: 0.003564  [ 3000/ 4500]
# Train loss: 0.003892  [ 4000/ 4500]
# Test Loss:  0.004706
#
# Epoch 34
# -------------------------------
# Train loss: 0.003899  [    0/ 4500]
# Train loss: 0.003845  [ 1000/ 4500]
# Train loss: 0.003598  [ 2000/ 4500]
# Train loss: 0.003556  [ 3000/ 4500]
# Train loss: 0.003894  [ 4000/ 4500]
# Test Loss:  0.004707
#
# Epoch 35
# -------------------------------
# Train loss: 0.003892  [    0/ 4500]
# Train loss: 0.003845  [ 1000/ 4500]
# Train loss: 0.003591  [ 2000/ 4500]
# Train loss: 0.003549  [ 3000/ 4500]
# Train loss: 0.003896  [ 4000/ 4500]
# Test Loss:  0.004707
#
# Epoch 36
# -------------------------------
# Train loss: 0.003888  [    0/ 4500]
# Train loss: 0.003847  [ 1000/ 4500]
# Train loss: 0.003584  [ 2000/ 4500]
# Train loss: 0.003542  [ 3000/ 4500]
# Train loss: 0.003898  [ 4000/ 4500]
# Test Loss:  0.004708
#
# Epoch 37
# -------------------------------
# Train loss: 0.003887  [    0/ 4500]
# Train loss: 0.003851  [ 1000/ 4500]
# Train loss: 0.003580  [ 2000/ 4500]
# Train loss: 0.003537  [ 3000/ 4500]
# Train loss: 0.003901  [ 4000/ 4500]
# Test Loss:  0.004709
#
# Epoch 38
# -------------------------------
# Train loss: 0.003887  [    0/ 4500]
# Train loss: 0.003856  [ 1000/ 4500]
# Train loss: 0.003577  [ 2000/ 4500]
# Train loss: 0.003533  [ 3000/ 4500]
# Train loss: 0.003903  [ 4000/ 4500]
# Test Loss:  0.004710
#
# Epoch 39
# -------------------------------
# Train loss: 0.003889  [    0/ 4500]
# Train loss: 0.003863  [ 1000/ 4500]
# Train loss: 0.003577  [ 2000/ 4500]
# Train loss: 0.003531  [ 3000/ 4500]
# Train loss: 0.003907  [ 4000/ 4500]
# Test Loss:  0.004712
#
# Epoch 40
# -------------------------------
# Train loss: 0.003891  [    0/ 4500]
# Train loss: 0.003872  [ 1000/ 4500]
# Train loss: 0.003578  [ 2000/ 4500]
# Train loss: 0.003532  [ 3000/ 4500]
# Train loss: 0.003911  [ 4000/ 4500]
# Test Loss:  0.004715
#
# Epoch 41
# -------------------------------
# Train loss: 0.003895  [    0/ 4500]
# Train loss: 0.003882  [ 1000/ 4500]
# Train loss: 0.003582  [ 2000/ 4500]
# Train loss: 0.003534  [ 3000/ 4500]
# Train loss: 0.003917  [ 4000/ 4500]
# Test Loss:  0.004719
#
# Epoch 42
# -------------------------------
# Train loss: 0.003898  [    0/ 4500]
# Train loss: 0.003895  [ 1000/ 4500]
# Train loss: 0.003588  [ 2000/ 4500]
# Train loss: 0.003537  [ 3000/ 4500]
# Train loss: 0.003922  [ 4000/ 4500]
# Test Loss:  0.004723
#
# Epoch 43
# -------------------------------
# Train loss: 0.003901  [    0/ 4500]
# Train loss: 0.003910  [ 1000/ 4500]
# Train loss: 0.003596  [ 2000/ 4500]
# Train loss: 0.003541  [ 3000/ 4500]
# Train loss: 0.003929  [ 4000/ 4500]
# Test Loss:  0.004728
#
# Epoch 44
# -------------------------------
# Train loss: 0.003902  [    0/ 4500]
# Train loss: 0.003709  [ 1000/ 4500]
# Train loss: 0.003396  [ 2000/ 4500]
# Train loss: 0.003294  [ 3000/ 4500]
# Train loss: 0.003737  [ 4000/ 4500]
# Test Loss:  0.004605
#
# Epoch 45
# -------------------------------
# Train loss: 0.003730  [    0/ 4500]
# Train loss: 0.003672  [ 1000/ 4500]
# Train loss: 0.003332  [ 2000/ 4500]
# Train loss: 0.003291  [ 3000/ 4500]
# Train loss: 0.003730  [ 4000/ 4500]
# Test Loss:  0.004604
#
# Epoch 46
# -------------------------------
# Train loss: 0.003707  [    0/ 4500]
# Train loss: 0.003660  [ 1000/ 4500]
# Train loss: 0.003327  [ 2000/ 4500]
# Train loss: 0.003299  [ 3000/ 4500]
# Train loss: 0.003728  [ 4000/ 4500]
# Test Loss:  0.004604
#
# Epoch 47
# -------------------------------
# Train loss: 0.003698  [    0/ 4500]
# Train loss: 0.003653  [ 1000/ 4500]
# Train loss: 0.003324  [ 2000/ 4500]
# Train loss: 0.003304  [ 3000/ 4500]
# Train loss: 0.003726  [ 4000/ 4500]
# Test Loss:  0.004605
#
# Epoch 48
# -------------------------------
# Train loss: 0.003693  [    0/ 4500]
# Train loss: 0.003649  [ 1000/ 4500]
# Train loss: 0.003322  [ 2000/ 4500]
# Train loss: 0.003308  [ 3000/ 4500]
# Train loss: 0.003725  [ 4000/ 4500]
# Test Loss:  0.004605
#
# Epoch 49
# -------------------------------
# Train loss: 0.003690  [    0/ 4500]
# Train loss: 0.003646  [ 1000/ 4500]
# Train loss: 0.003321  [ 2000/ 4500]
# Train loss: 0.003312  [ 3000/ 4500]
# Train loss: 0.003723  [ 4000/ 4500]
# Test Loss:  0.004605
#
# Epoch 50
# -------------------------------
# Train loss: 0.003688  [    0/ 4500]
# Train loss: 0.003644  [ 1000/ 4500]
# Train loss: 0.003321  [ 2000/ 4500]
# Train loss: 0.003314  [ 3000/ 4500]
# Train loss: 0.003723  [ 4000/ 4500]
# Test Loss:  0.004604
#
# Epoch 51
# -------------------------------
# Train loss: 0.003687  [    0/ 4500]
# Train loss: 0.003643  [ 1000/ 4500]
# Train loss: 0.003320  [ 2000/ 4500]
# Train loss: 0.003316  [ 3000/ 4500]
# Train loss: 0.003722  [ 4000/ 4500]
# Test Loss:  0.004604
#
# Epoch 52
# -------------------------------
# Train loss: 0.003686  [    0/ 4500]
# Train loss: 0.003642  [ 1000/ 4500]
# Train loss: 0.003320  [ 2000/ 4500]
# Train loss: 0.003318  [ 3000/ 4500]
# Train loss: 0.003722  [ 4000/ 4500]
# Test Loss:  0.004604
#
# Epoch 53
# -------------------------------
# Train loss: 0.003685  [    0/ 4500]
# Train loss: 0.003641  [ 1000/ 4500]
# Train loss: 0.003320  [ 2000/ 4500]
# Train loss: 0.003320  [ 3000/ 4500]
# Train loss: 0.003722  [ 4000/ 4500]
# Test Loss:  0.004604
#
# Epoch 54
# -------------------------------
# Train loss: 0.003685  [    0/ 4500]
# Train loss: 0.003640  [ 1000/ 4500]
# Train loss: 0.003320  [ 2000/ 4500]
# Train loss: 0.003322  [ 3000/ 4500]
# Train loss: 0.003722  [ 4000/ 4500]
# Test Loss:  0.004604
#
# Epoch 55
# -------------------------------
# Train loss: 0.003685  [    0/ 4500]
# Train loss: 0.003640  [ 1000/ 4500]
# Train loss: 0.003320  [ 2000/ 4500]
# Train loss: 0.003324  [ 3000/ 4500]
# Train loss: 0.003722  [ 4000/ 4500]
# Test Loss:  0.004604
#
# Epoch 56
# -------------------------------
# Train loss: 0.003686  [    0/ 4500]
# Train loss: 0.003640  [ 1000/ 4500]
# Train loss: 0.003320  [ 2000/ 4500]
# Train loss: 0.003325  [ 3000/ 4500]
# Train loss: 0.003722  [ 4000/ 4500]
# Test Loss:  0.004604
#
# Epoch 57
# -------------------------------
# Train loss: 0.003686  [    0/ 4500]
# Train loss: 0.003617  [ 1000/ 4500]
# Train loss: 0.003303  [ 2000/ 4500]
# Train loss: 0.003283  [ 3000/ 4500]
# Train loss: 0.003676  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 58
# -------------------------------
# Train loss: 0.003644  [    0/ 4500]
# Train loss: 0.003604  [ 1000/ 4500]
# Train loss: 0.003294  [ 2000/ 4500]
# Train loss: 0.003283  [ 3000/ 4500]
# Train loss: 0.003676  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 59
# -------------------------------
# Train loss: 0.003642  [    0/ 4500]
# Train loss: 0.003604  [ 1000/ 4500]
# Train loss: 0.003296  [ 2000/ 4500]
# Train loss: 0.003285  [ 3000/ 4500]
# Train loss: 0.003676  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 60
# -------------------------------
# Train loss: 0.003640  [    0/ 4500]
# Train loss: 0.003604  [ 1000/ 4500]
# Train loss: 0.003297  [ 2000/ 4500]
# Train loss: 0.003286  [ 3000/ 4500]
# Train loss: 0.003676  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 61
# -------------------------------
# Train loss: 0.003638  [    0/ 4500]
# Train loss: 0.003604  [ 1000/ 4500]
# Train loss: 0.003297  [ 2000/ 4500]
# Train loss: 0.003287  [ 3000/ 4500]
# Train loss: 0.003676  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 62
# -------------------------------
# Train loss: 0.003636  [    0/ 4500]
# Train loss: 0.003603  [ 1000/ 4500]
# Train loss: 0.003298  [ 2000/ 4500]
# Train loss: 0.003288  [ 3000/ 4500]
# Train loss: 0.003676  [ 4000/ 4500]
# Test Loss:  0.004598
#
# Epoch 63
# -------------------------------
# Train loss: 0.003635  [    0/ 4500]
# Train loss: 0.003603  [ 1000/ 4500]
# Train loss: 0.003298  [ 2000/ 4500]
# Train loss: 0.003288  [ 3000/ 4500]
# Train loss: 0.003676  [ 4000/ 4500]
# Test Loss:  0.004598
#
# Epoch 64
# -------------------------------
# Train loss: 0.003634  [    0/ 4500]
# Train loss: 0.003603  [ 1000/ 4500]
# Train loss: 0.003299  [ 2000/ 4500]
# Train loss: 0.003289  [ 3000/ 4500]
# Train loss: 0.003677  [ 4000/ 4500]
# Test Loss:  0.004598
#
# Epoch 65
# -------------------------------
# Train loss: 0.003633  [    0/ 4500]
# Train loss: 0.003603  [ 1000/ 4500]
# Train loss: 0.003299  [ 2000/ 4500]
# Train loss: 0.003289  [ 3000/ 4500]
# Train loss: 0.003677  [ 4000/ 4500]
# Test Loss:  0.004598
#
# Epoch 66
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003603  [ 1000/ 4500]
# Train loss: 0.003299  [ 2000/ 4500]
# Train loss: 0.003289  [ 3000/ 4500]
# Train loss: 0.003677  [ 4000/ 4500]
# Test Loss:  0.004598
#
# Epoch 67
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003603  [ 1000/ 4500]
# Train loss: 0.003300  [ 2000/ 4500]
# Train loss: 0.003290  [ 3000/ 4500]
# Train loss: 0.003677  [ 4000/ 4500]
# Test Loss:  0.004598
#
# Epoch 68
# -------------------------------
# Train loss: 0.003631  [    0/ 4500]
# Train loss: 0.003603  [ 1000/ 4500]
# Train loss: 0.003300  [ 2000/ 4500]
# Train loss: 0.003290  [ 3000/ 4500]
# Train loss: 0.003677  [ 4000/ 4500]
# Test Loss:  0.004598
#
# Epoch 69
# -------------------------------
# Train loss: 0.003630  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003291  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003670  [ 4000/ 4500]
# Test Loss:  0.004598
#
# Epoch 70
# -------------------------------
# Train loss: 0.003631  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003670  [ 4000/ 4500]
# Test Loss:  0.004598
#
# Epoch 71
# -------------------------------
# Train loss: 0.003631  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003669  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 72
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003669  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 73
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003293  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003669  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 74
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003293  [ 2000/ 4500]
# Train loss: 0.003285  [ 3000/ 4500]
# Train loss: 0.003669  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 75
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003293  [ 2000/ 4500]
# Train loss: 0.003285  [ 3000/ 4500]
# Train loss: 0.003669  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 76
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003293  [ 2000/ 4500]
# Train loss: 0.003285  [ 3000/ 4500]
# Train loss: 0.003669  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 77
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003293  [ 2000/ 4500]
# Train loss: 0.003285  [ 3000/ 4500]
# Train loss: 0.003669  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 78
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003293  [ 2000/ 4500]
# Train loss: 0.003285  [ 3000/ 4500]
# Train loss: 0.003669  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 79
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003293  [ 2000/ 4500]
# Train loss: 0.003285  [ 3000/ 4500]
# Train loss: 0.003669  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 80
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 81
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 82
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 83
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 84
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 85
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 86
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003293  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 87
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003293  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 88
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003293  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 89
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003293  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 90
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003599  [ 1000/ 4500]
# Train loss: 0.003293  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 91
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 92
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 93
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 94
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 95
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 96
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 97
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 98
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 99
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 100
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 101
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 102
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 103
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 104
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 105
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 106
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 107
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 108
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 109
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 110
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 111
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 112
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 113
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 114
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 115
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 116
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 117
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 118
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 119
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 120
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 121
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 122
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 123
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 124
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 125
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 126
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 127
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 128
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 129
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 130
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 131
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 132
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 133
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 134
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 135
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 136
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 137
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 138
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 139
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 140
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 141
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 142
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 143
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 144
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 145
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 146
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 147
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 148
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 149
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 150
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 151
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 152
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 153
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 154
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 155
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 156
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 157
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 158
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 159
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 160
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 161
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 162
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 163
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 164
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 165
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 166
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 167
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 168
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 169
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 170
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 171
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 172
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 173
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 174
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 175
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 176
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 177
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 178
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 179
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 180
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 181
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 182
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 183
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 184
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 185
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 186
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 187
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 188
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 189
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 190
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 191
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 192
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 193
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 194
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 195
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 196
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 197
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 198
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 199
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Epoch 200
# -------------------------------
# Train loss: 0.003632  [    0/ 4500]
# Train loss: 0.003598  [ 1000/ 4500]
# Train loss: 0.003292  [ 2000/ 4500]
# Train loss: 0.003284  [ 3000/ 4500]
# Train loss: 0.003668  [ 4000/ 4500]
# Test Loss:  0.004597
#
# Done!

# %%
# %%
plt.figure(figsize = (8,6))
plt.title("MSE Loss vs Epochs")
plt.plot(steps, torch.FloatTensor(Loss_train).cpu(), label = 'train')
plt.plot(steps, Loss_test, label = 'test')
plt.xlabel("Epochs")
plt.ylabel("MSE Loss")
plt.legend()
plt.show()
        
#%%
torch.cuda.empty_cache()
#%%


#%%
# figure configuration
font = {'family' : 'Arial',
        'weight' : 'bold',
        'size'   : 22}

plt.rc('font', **font)

# %%
torch.save(model.state_dict(), 'model/exp_mlmodel5.dat')

#%%  test model

test_model = NeuralNetwork().to('cpu')
# test_model =UNet().to('cpu')

test_model.load_state_dict(torch.load('model/exp_mlmodel5.dat'))
# Out:
# <All keys matched successfully>

# %%
md = test_model.state_dict()
Ts = md['my1.weights1']
plt.figure(figsize = (10,10))
plt.imshow(Ts[0:1000,:],cmap = 'rainbow')
plt.colorbar()
plt.show()

# %%
import pickle

with open("matrix/FT75_matrix.dat", 'wb') as f:
    pickle.dump(Ts, f)

print("finished")
# Out:
# finished

# %%
test_number = np.random.randint(0,50)

with torch.no_grad():
    test_model.eval()
    X= x_test[test_number].reshape(-1,1,*input_dim)
    pred = test_model(X)
plt.figure(figsize = (10,8)) 
plt.subplot(121)
plt.imshow(y_test[test_number].reshape(output_dim), cmap = 'gray')  
plt.subplot(122)
plt.imshow(pred[0].reshape(output_dim), cmap = 'gray')
# plt.imshow(pred[0].reshape(64,64))
plt.show()

# %% [markdown]
# ## Test use different temperature

# %%
with open("data/Temperature/Speckle_400um_Digits_M6_T25forT75_112x112_5000.dat", 'rb') as f:
    i_list = pickle.load(f)

# with open("data/Temperature/Digits_5000.dat", 'rb') as f:
#     output_list =pickle.load(f)
    
test_i = 100

sample = torch.FloatTensor(i_list[test_i]/255.0)
sample_ground = torch.FloatTensor(output_list[test_i]/255.0)
    
with torch.no_grad():
    test_model.eval()
    X= sample.reshape(-1,1,*input_dim)
    pred = test_model(X)
plt.figure(figsize = (10,8)) 
plt.subplot(121)
plt.imshow(sample_ground.reshape(output_dim), cmap = 'gray')  
plt.axis('off')
plt.subplot(122)
plt.imshow(pred[0].reshape(output_dim), cmap = 'gray')
# plt.imshow(pred[0].reshape(64,64))
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-129-c59a2ed252f0> in <module>
#      16 plt.figure(figsize = (10,8))
#      17 plt.subplot(121)
# ---> 18 plt.imshow(sample_ground.reshape(output_dim), cmap = 'gray')
#      19 plt.axis('off')
#      20 plt.subplot(122)
#
# RuntimeError: shape '[112, 112]' is invalid for input of size 784

# %%
#%%
test_number = np.random.randint(0,90)

with torch.no_grad():
    test_model.eval()
    X= x_train[test_number].reshape(-1,1,*input_dim)
    pred = test_model(X)
plt.figure(figsize = (10,8)) 
plt.subplot(121)
plt.imshow(y_train[test_number].reshape(output_dim), cmap = 'gray')  
plt.subplot(122)
plt.imshow(pred[0].reshape(output_dim), cmap = 'gray')

plt.show()

#%%
# test_number = np.random.randint(0,500)

# with torch.no_grad():
#     test_model.eval()
#     X = x_train[test_number].reshape(-1,1, *input_dim)
#     pred = test_model(X)
  
# plt.figure() 

# plt.subplot(121)
# plt.imshow(y_train[test_number].reshape(64,64), cmap = 'gray')  
# plt.subplot(122)
# plt.imshow(pred[0].reshape(64,64), cmap = 'gray')
# plt.show()
